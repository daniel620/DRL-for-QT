# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# 分辨率200
plt.rcParams['savefig.dpi'] = 200
stock_df = pd.read_csv('/home/zuohaolan/_WorkSpace/projects/DRL-for-QT/PB_ROE/stocks_list.csv')
stock_df.head()
# Out:
#      ts_code  symbol  name area industry
# 0  000001.SZ       1  平安银行   深圳       银行
# 1  000069.SZ      69  华侨城A   深圳     全国地产
# 2  000157.SZ     157  中联重科   湖南     工程机械
# 3  000725.SZ     725  京东方A   北京      元器件
# 4  000768.SZ     768  中航西飞   陕西       航空

# %%
stock_df.value_counts('industry').shape
# Out:
# (24,)

# %%
# 根据行业分类画柱状图
stock_df.value_counts('industry').plot(kind='bar', figsize=(20, 10))
plt.show()
# Out:
# /home/zuohaolan/anaconda3/envs/py38/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 38134 (\N{CJK UNIFIED IDEOGRAPH-94F6}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/zuohaolan/anaconda3/envs/py38/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 34892 (\N{CJK UNIFIED IDEOGRAPH-884C}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/zuohaolan/anaconda3/envs/py38/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 35777 (\N{CJK UNIFIED IDEOGRAPH-8BC1}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# /home/zuohaolan/anaconda3/envs/py38/lib/python3.8/site-packages/IPython/core/pylabtools.py:152: UserWarning: Glyph 21048 (\N{CJK UNIFIED IDEOGRAPH-5238}) missing from current font.
#   fig.canvas.print_figure(bytes_io, **kw)
# ...
