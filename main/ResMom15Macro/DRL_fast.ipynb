# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %%
# select stocks
res_mom = pd.read_csv('../../PB_ROE/res_mom.csv')
# first 15 stocks
res_mom_15 = res_mom.iloc[:15,:]
# to list
res_mom_15_list = res_mom_15['ts_code'].to_list()
res_mom_15_list
# Out:
# ['002594.SZ',
#  '002304.SZ',
#  '000768.SZ',
#  '600660.SH',
#  '601788.SH',
#  '000725.SZ',
#  '000001.SZ',
#  '601628.SH',
#  '601601.SH',
#  '002008.SZ',
#  '600016.SH',
#  '600104.SH',
#  '000858.SZ',
#  '600111.SH',
#  '600036.SH']

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])
TRAIN_START_DATE = '2016-01-01'
TRAIN_END_DATE = '2021-01-01'
TEST_START_DATE = '2021-01-01'
TEST_END_DATE = '2023-01-01'
# processed = pd.read_csv('datasets/SSE_processed.csv')
# TRAIN_START_DATE='2016-01-01'
# TRAIN_END_DATE='2020-06-01'
# TEST_START_DATE='2020-06-01'
# # TEST_END_DATE='2023-01-01'
# TEST_END_DATE='2022-01-01'


processed = pd.read_csv('datasets/processed_tech_macro_pb.csv')
ticket_list = res_mom_15_list
processed = processed[processed['tic'].isin(ticket_list)]
# sort ????
processed = processed.sort_values(['date','tic'],ignore_index=True)
print(processed.shape)
# processed.sample(5)
processed.tic.value_counts()
# Out:
# (25545, 24)
# 000001.SZ    1703
# 000725.SZ    1703
# 000768.SZ    1703
# 000858.SZ    1703
# 002008.SZ    1703
# 002304.SZ    1703
# 002594.SZ    1703
# 600016.SH    1703
# 600036.SH    1703
# 600104.SH    1703
# 600111.SH    1703
# 600660.SH    1703
# 601601.SH    1703
# 601628.SH    1703
# 601788.SH    1703
# Name: tic, dtype: int64

# %%
print(processed.columns)
print(INDICATORS)
# Out:
# Index(['date', 'tic', 'open', 'high', 'low', 'close', 'volume', 'day', 'macd',
#        'boll_ub', 'boll_lb', 'rsi_30', 'cci_30', 'dx_30', 'close_30_sma',
#        'close_60_sma', 'turbulence', '1m', 'month_year', 'CLI', 'CCI', 'BCI',
#        'turnover_rate', 'pb'],
#       dtype='object')
# ['macd', 'boll_ub', 'boll_lb', 'rsi_30', 'cci_30', 'dx_30', 'close_30_sma', 'close_60_sma']

# %%
INDICATORS.append('turnover_rate')
INDICATORS.append('pb')
INDICATORS.append('day')
INDICATORS.append('close')
INDICATORS.append('1m')
INDICATORS.append('CLI')
INDICATORS.append('CCI')
INDICATORS.append('BCI')
print(INDICATORS)
# Out:
# ['macd', 'boll_ub', 'boll_lb', 'rsi_30', 'cci_30', 'dx_30', 'close_30_sma', 'close_60_sma', 'turnover_rate', 'pb', 'day', 'close', '1m', 'CLI', 'CCI', 'BCI']

# %%
# 重新import DRLEnsembleAgent
import importlib
# from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
importlib.reload(sys.modules['finrl.agents.stablebaselines3.models'])
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5    
}

rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

# A2C_model_kwargs = {
#                     'n_steps': 5,
#                     'ent_coef': 0.005,
#                     'learning_rate': 0.0007
#                     }
A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.01,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    "batch_size": 512
                    }

# DDPG_model_kwargs = {
#                       #"action_noise":"ornstein_uhlenbeck",
#                       "buffer_size": 10_000,
#                       "learning_rate": 0.0005,
#                       "batch_size": 64
#                     }
DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 50_000,
                      "learning_rate": 0.001,
                      "batch_size": 512
                    }

# timesteps_dict = {'a2c' : 10_000, 
#                  'ppo' : 10_000, 
#                  'ddpg' : 10_000
#                  }
timesteps_dict = {'a2c' : 50_000, 
                 'ppo' : 50_000, 
                 'ddpg' : 50_000
                 }
# Out:
# Stock Dimension: 15, State Space: 151

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  375.90577053030336
# ======Model training from:  2016-01-01 to  2021-01-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_126_1
# -------------------------------------
# | time/                 |           |
# |    fps                | 208       |
# |    iterations         | 100       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -21.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 76        |
# |    reward             | 0.3905794 |
# |    std                | 1.01      |
# |    value_loss         | 15.1      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 232       |
# |    iterations         | 200       |
# |    time_elapsed       | 4         |
# |    total_timesteps    | 1000      |
# | train/                |           |
# |    entropy_loss       | -21.3     |
# |    explained_variance | 0.0169    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 199       |
# |    policy_loss        | -12.1     |
# |    reward             | 1.1543753 |
# |    std                | 1         |
# |    value_loss         | 29.9      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 242        |
# |    iterations         | 300        |
# |    time_elapsed       | 6          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -21.4      |
# |    explained_variance | -0.0498    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -7.19      |
# |    reward             | 0.20945776 |
# |    std                | 1          |
# |    value_loss         | 2.21       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 244        |
# |    iterations         | 400        |
# |    time_elapsed       | 8          |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -21.3      |
# |    explained_variance | -0.229     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 41.5       |
# |    reward             | -1.1911155 |
# |    std                | 1          |
# |    value_loss         | 9.17       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 246       |
# |    iterations         | 500       |
# |    time_elapsed       | 10        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -21.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 9.19      |
# |    reward             | 0.1375239 |
# |    std                | 1.01      |
# |    value_loss         | 0.291     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 600       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 3000      |
# | train/                |           |
# |    entropy_loss       | -21.3     |
# |    explained_variance | 0.33      |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 599       |
# |    policy_loss        | 8.58      |
# |    reward             | -2.510923 |
# |    std                | 1         |
# |    value_loss         | 2.75      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 253         |
# |    iterations         | 700         |
# |    time_elapsed       | 13          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -21.3       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | 63.8        |
# |    reward             | -0.90781105 |
# |    std                | 1           |
# |    value_loss         | 12.1        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 254       |
# |    iterations         | 800       |
# |    time_elapsed       | 15        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -21.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | 47.7      |
# |    reward             | 1.9637774 |
# |    std                | 1.01      |
# |    value_loss         | 5.42      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 255         |
# |    iterations         | 900         |
# |    time_elapsed       | 17          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -21.4       |
# |    explained_variance | -0.366      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | 37.3        |
# |    reward             | -0.14295916 |
# |    std                | 1.01        |
# |    value_loss         | 4.67        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 255        |
# |    iterations         | 1000       |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -21.4      |
# |    explained_variance | -0.0773    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 99.9       |
# |    reward             | -1.4860215 |
# |    std                | 1.01       |
# |    value_loss         | 22.7       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 256        |
# |    iterations         | 1100       |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -21.4      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | 93.4       |
# |    reward             | 0.15246092 |
# |    std                | 1.01       |
# |    value_loss         | 22.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 1200      |
# |    time_elapsed       | 23        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -21.4     |
# |    explained_variance | -0.069    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -35.3     |
# |    reward             | -3.934503 |
# |    std                | 1.01      |
# |    value_loss         | 5.68      |
# -------------------------------------
# day: 1217, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 3932488.68
# total_reward: 2932488.68
# total_cost: 15305.89
# total_trades: 13242
# Sharpe: 1.242
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 1300      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -21.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 74.7      |
# |    reward             | -2.341496 |
# |    std                | 1.01      |
# |    value_loss         | 20.1      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 1400      |
# |    time_elapsed       | 27        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -21.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -0.196    |
# |    reward             | 0.7954195 |
# |    std                | 1.01      |
# |    value_loss         | 4.29      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 1500      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -21.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -3.3      |
# |    reward             | -0.332361 |
# |    std                | 1.01      |
# |    value_loss         | 1.6       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 257        |
# |    iterations         | 1600       |
# |    time_elapsed       | 31         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -21.5      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | -197       |
# |    reward             | -2.2323475 |
# |    std                | 1.01       |
# |    value_loss         | 125        |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 258      |
# |    iterations         | 1700     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -21.5    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | 158      |
# |    reward             | 7.027091 |
# |    std                | 1.02     |
# |    value_loss         | 55.8     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 257       |
# |    iterations         | 1800      |
# |    time_elapsed       | 34        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -21.6     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | 51.9      |
# |    reward             | -4.174632 |
# |    std                | 1.02      |
# |    value_loss         | 13.4      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 258         |
# |    iterations         | 1900        |
# |    time_elapsed       | 36          |
# |    total_timesteps    | 9500        |
# | train/                |             |
# |    entropy_loss       | -21.6       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1899        |
# |    policy_loss        | -27.6       |
# |    reward             | -0.70472765 |
# |    std                | 1.02        |
# |    value_loss         | 2.49        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 258        |
# |    iterations         | 2000       |
# |    time_elapsed       | 38         |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -21.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | -36.6      |
# |    reward             | -0.8994527 |
# |    std                | 1.02       |
# |    value_loss         | 2.8        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 258       |
# |    iterations         | 2100      |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -21.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | -0.666    |
# |    reward             | 3.2276304 |
# |    std                | 1.02      |
# |    value_loss         | 2.5       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 258        |
# |    iterations         | 2200       |
# |    time_elapsed       | 42         |
# |    total_timesteps    | 11000      |
# | train/                |            |
# |    entropy_loss       | -21.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2199       |
# |    policy_loss        | -49.8      |
# |    reward             | 0.60648483 |
# |    std                | 1.02       |
# |    value_loss         | 6.07       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 258        |
# |    iterations         | 2300       |
# |    time_elapsed       | 44         |
# |    total_timesteps    | 11500      |
# | train/                |            |
# |    entropy_loss       | -21.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2299       |
# |    policy_loss        | -41.4      |
# |    reward             | -1.2530622 |
# |    std                | 1.02       |
# |    value_loss         | 7.26       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 258        |
# |    iterations         | 2400       |
# |    time_elapsed       | 46         |
# |    total_timesteps    | 12000      |
# | train/                |            |
# |    entropy_loss       | -21.6      |
# |    explained_variance | 0.0155     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2399       |
# |    policy_loss        | -80        |
# |    reward             | 0.48297262 |
# |    std                | 1.02       |
# |    value_loss         | 23.2       |
# --------------------------------------
# day: 1217, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 3733964.46
# total_reward: 2733964.46
# total_cost: 17703.55
# total_trades: 13890
# Sharpe: 1.267
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 258         |
# |    iterations         | 2500        |
# |    time_elapsed       | 48          |
# |    total_timesteps    | 12500       |
# | train/                |             |
# |    entropy_loss       | -21.6       |
# |    explained_variance | 4.17e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2499        |
# |    policy_loss        | 21.9        |
# |    reward             | -0.34632948 |
# |    std                | 1.02        |
# |    value_loss         | 1.5         |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 258        |
# |    iterations         | 2600       |
# |    time_elapsed       | 50         |
# |    total_timesteps    | 13000      |
# | train/                |            |
# |    entropy_loss       | -21.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2599       |
# |    policy_loss        | 40.6       |
# |    reward             | -2.4093585 |
# |    std                | 1.02       |
# |    value_loss         | 11.8       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 258      |
# |    iterations         | 2700     |
# |    time_elapsed       | 52       |
# |    total_timesteps    | 13500    |
# | train/                |          |
# |    entropy_loss       | -21.6    |
# |    explained_variance | -0.469   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2699     |
# |    policy_loss        | -22.1    |
# |    reward             | 1.838834 |
# |    std                | 1.02     |
# |    value_loss         | 1.63     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 258       |
# |    iterations         | 2800      |
# |    time_elapsed       | 54        |
# |    total_timesteps    | 14000     |
# | train/                |           |
# |    entropy_loss       | -21.6     |
# |    explained_variance | 0.0221    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2799      |
# |    policy_loss        | 18.6      |
# |    reward             | 0.6256463 |
# |    std                | 1.02      |
# |    value_loss         | 9.47      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 258        |
# |    iterations         | 2900       |
# |    time_elapsed       | 56         |
# |    total_timesteps    | 14500      |
# | train/                |            |
# |    entropy_loss       | -21.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2899       |
# |    policy_loss        | 225        |
# |    reward             | -5.3534665 |
# |    std                | 1.03       |
# |    value_loss         | 158        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 258       |
# |    iterations         | 3000      |
# |    time_elapsed       | 57        |
# |    total_timesteps    | 15000     |
# | train/                |           |
# |    entropy_loss       | -21.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2999      |
# |    policy_loss        | 18.7      |
# |    reward             | 2.3633938 |
# |    std                | 1.03      |
# |    value_loss         | 5.01      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 258       |
# |    iterations         | 3100      |
# |    time_elapsed       | 59        |
# |    total_timesteps    | 15500     |
# | train/                |           |
# |    entropy_loss       | -21.7     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3099      |
# |    policy_loss        | 76.2      |
# |    reward             | 2.8858094 |
# |    std                | 1.03      |
# |    value_loss         | 13.1      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 258        |
# |    iterations         | 3200       |
# |    time_elapsed       | 61         |
# |    total_timesteps    | 16000      |
# | train/                |            |
# |    entropy_loss       | -21.7      |
# |    explained_variance | 0.108      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3199       |
# |    policy_loss        | -32        |
# |    reward             | 0.25851986 |
# |    std                | 1.03       |
# |    value_loss         | 2.88       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 258      |
# |    iterations         | 3300     |
# |    time_elapsed       | 63       |
# |    total_timesteps    | 16500    |
# | train/                |          |
# |    entropy_loss       | -21.7    |
# |    explained_variance | -0.38    |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3299     |
# |    policy_loss        | 24.9     |
# |    reward             | 5.956653 |
# |    std                | 1.03     |
# |    value_loss         | 4.29     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 259       |
# |    iterations         | 3400      |
# |    time_elapsed       | 65        |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -21.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | 461       |
# |    reward             | 1.9560773 |
# |    std                | 1.03      |
# |    value_loss         | 980       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 258      |
# |    iterations         | 3500     |
# |    time_elapsed       | 67       |
# |    total_timesteps    | 17500    |
# | train/                |          |
# |    entropy_loss       | -21.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3499     |
# |    policy_loss        | 155      |
# |    reward             | 5.620355 |
# |    std                | 1.03     |
# |    value_loss         | 84.5     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 258        |
# |    iterations         | 3600       |
# |    time_elapsed       | 69         |
# |    total_timesteps    | 18000      |
# | train/                |            |
# |    entropy_loss       | -21.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3599       |
# |    policy_loss        | -53.6      |
# |    reward             | -0.8270124 |
# |    std                | 1.03       |
# |    value_loss         | 11.3       |
# --------------------------------------
# day: 1217, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 8946045.83
# total_reward: 7946045.83
# total_cost: 11946.36
# total_trades: 10075
# Sharpe: 1.489
# =================================
# ------------------------------------
# | time/                 |          |
# |    fps                | 259      |
# |    iterations         | 3700     |
# |    time_elapsed       | 71       |
# |    total_timesteps    | 18500    |
# | train/                |          |
# |    entropy_loss       | -21.7    |
# |    explained_variance | -0.196   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3699     |
# |    policy_loss        | -25.9    |
# |    reward             | 1.231992 |
# |    std                | 1.03     |
# |    value_loss         | 4.36     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 259       |
# |    iterations         | 3800      |
# |    time_elapsed       | 73        |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -21.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | -123      |
# |    reward             | 2.1463552 |
# |    std                | 1.03      |
# |    value_loss         | 41.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 259       |
# |    iterations         | 3900      |
# |    time_elapsed       | 75        |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -21.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -15.1     |
# |    reward             | -0.333138 |
# |    std                | 1.03      |
# |    value_loss         | 0.544     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 259        |
# |    iterations         | 4000       |
# |    time_elapsed       | 76         |
# |    total_timesteps    | 20000      |
# | train/                |            |
# |    entropy_loss       | -21.8      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3999       |
# |    policy_loss        | -411       |
# |    reward             | -12.373662 |
# |    std                | 1.03       |
# |    value_loss         | 360        |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 260      |
# |    iterations         | 4100     |
# |    time_elapsed       | 78       |
# |    total_timesteps    | 20500    |
# | train/                |          |
# |    entropy_loss       | -21.8    |
# |    explained_variance | 0.0435   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4099     |
# |    policy_loss        | -106     |
# |    reward             | 4.990013 |
# |    std                | 1.03     |
# |    value_loss         | 83.9     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 260       |
# |    iterations         | 4200      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -21.7     |
# |    explained_variance | -0.00173  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | 15.8      |
# |    reward             | 5.2011867 |
# |    std                | 1.03      |
# |    value_loss         | 1.78      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 260      |
# |    iterations         | 4300     |
# |    time_elapsed       | 82       |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -21.7    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | 423      |
# |    reward             | 17.51725 |
# |    std                | 1.03     |
# |    value_loss         | 519      |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 260        |
# |    iterations         | 4400       |
# |    time_elapsed       | 84         |
# |    total_timesteps    | 22000      |
# | train/                |            |
# |    entropy_loss       | -21.7      |
# |    explained_variance | 0.185      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4399       |
# |    policy_loss        | -27.8      |
# |    reward             | 0.14484556 |
# |    std                | 1.03       |
# |    value_loss         | 1.9        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 260       |
# |    iterations         | 4500      |
# |    time_elapsed       | 86        |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -21.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | 133       |
# |    reward             | -3.631501 |
# |    std                | 1.03      |
# |    value_loss         | 58        |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 260       |
# |    iterations         | 4600      |
# |    time_elapsed       | 88        |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -21.8     |
# |    explained_variance | 0.0178    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | 55.3      |
# |    reward             | 2.1616902 |
# |    std                | 1.04      |
# |    value_loss         | 8.48      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 260      |
# |    iterations         | 4700     |
# |    time_elapsed       | 90       |
# |    total_timesteps    | 23500    |
# | train/                |          |
# |    entropy_loss       | -21.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4699     |
# |    policy_loss        | -22.8    |
# |    reward             | 3.284961 |
# |    std                | 1.04     |
# |    value_loss         | 7.99     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 260       |
# |    iterations         | 4800      |
# |    time_elapsed       | 92        |
# |    total_timesteps    | 24000     |
# | train/                |           |
# |    entropy_loss       | -21.8     |
# |    explained_variance | 0.00111   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4799      |
# |    policy_loss        | 151       |
# |    reward             | 5.8178167 |
# |    std                | 1.04      |
# |    value_loss         | 98.2      |
# -------------------------------------
# day: 1217, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 5236553.81
# total_reward: 4236553.81
# total_cost: 8020.20
# total_trades: 10163
# Sharpe: 1.344
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 260        |
# |    iterations         | 4900       |
# |    time_elapsed       | 93         |
# |    total_timesteps    | 24500      |
# | train/                |            |
# |    entropy_loss       | -21.8      |
# |    explained_variance | -0.021     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4899       |
# |    policy_loss        | -52.2      |
# |    reward             | -0.5591291 |
# |    std                | 1.04       |
# |    value_loss         | 7.13       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 260        |
# |    iterations         | 5000       |
# |    time_elapsed       | 95         |
# |    total_timesteps    | 25000      |
# | train/                |            |
# |    entropy_loss       | -21.8      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4999       |
# |    policy_loss        | 92.6       |
# |    reward             | -1.6324421 |
# |    std                | 1.04       |
# |    value_loss         | 25.2       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 261        |
# |    iterations         | 5100       |
# |    time_elapsed       | 97         |
# |    total_timesteps    | 25500      |
# | train/                |            |
# |    entropy_loss       | -21.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5099       |
# |    policy_loss        | 117        |
# |    reward             | -4.3257847 |
# |    std                | 1.04       |
# |    value_loss         | 56.4       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 5200      |
# |    time_elapsed       | 99        |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -21.8     |
# |    explained_variance | -0.0942   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | -7.7      |
# |    reward             | 1.1839193 |
# |    std                | 1.04      |
# |    value_loss         | 3         |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 5300      |
# |    time_elapsed       | 101       |
# |    total_timesteps    | 26500     |
# | train/                |           |
# |    entropy_loss       | -21.8     |
# |    explained_variance | -0.000404 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5299      |
# |    policy_loss        | 28.7      |
# |    reward             | -5.211583 |
# |    std                | 1.04      |
# |    value_loss         | 6.18      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 261        |
# |    iterations         | 5400       |
# |    time_elapsed       | 103        |
# |    total_timesteps    | 27000      |
# | train/                |            |
# |    entropy_loss       | -21.8      |
# |    explained_variance | -0.885     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5399       |
# |    policy_loss        | -4.65      |
# |    reward             | 0.28552923 |
# |    std                | 1.03       |
# |    value_loss         | 0.171      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 261        |
# |    iterations         | 5500       |
# |    time_elapsed       | 105        |
# |    total_timesteps    | 27500      |
# | train/                |            |
# |    entropy_loss       | -21.8      |
# |    explained_variance | -0.0907    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5499       |
# |    policy_loss        | -11.8      |
# |    reward             | -0.7708567 |
# |    std                | 1.04       |
# |    value_loss         | 2.91       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 5600     |
# |    time_elapsed       | 106      |
# |    total_timesteps    | 28000    |
# | train/                |          |
# |    entropy_loss       | -21.8    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5599     |
# |    policy_loss        | 186      |
# |    reward             | 7.857808 |
# |    std                | 1.04     |
# |    value_loss         | 102      |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 5700     |
# |    time_elapsed       | 108      |
# |    total_timesteps    | 28500    |
# | train/                |          |
# |    entropy_loss       | -21.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5699     |
# |    policy_loss        | 239      |
# |    reward             | 5.262475 |
# |    std                | 1.04     |
# |    value_loss         | 161      |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 261        |
# |    iterations         | 5800       |
# |    time_elapsed       | 110        |
# |    total_timesteps    | 29000      |
# | train/                |            |
# |    entropy_loss       | -21.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5799       |
# |    policy_loss        | 140        |
# |    reward             | -3.9105084 |
# |    std                | 1.04       |
# |    value_loss         | 42.1       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 5900      |
# |    time_elapsed       | 112       |
# |    total_timesteps    | 29500     |
# | train/                |           |
# |    entropy_loss       | -21.8     |
# |    explained_variance | -1.19e-05 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5899      |
# |    policy_loss        | -32.9     |
# |    reward             | 0.8277469 |
# |    std                | 1.04      |
# |    value_loss         | 3.1       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 6000      |
# |    time_elapsed       | 114       |
# |    total_timesteps    | 30000     |
# | train/                |           |
# |    entropy_loss       | -21.9     |
# |    explained_variance | 0.0761    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5999      |
# |    policy_loss        | 44.1      |
# |    reward             | 7.6749635 |
# |    std                | 1.04      |
# |    value_loss         | 13.2      |
# -------------------------------------
# day: 1217, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 4502241.26
# total_reward: 3502241.26
# total_cost: 13876.86
# total_trades: 8950
# Sharpe: 1.328
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 6100      |
# |    time_elapsed       | 116       |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -21.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | -12.7     |
# |    reward             | 1.7358962 |
# |    std                | 1.04      |
# |    value_loss         | 0.549     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 6200      |
# |    time_elapsed       | 118       |
# |    total_timesteps    | 31000     |
# | train/                |           |
# |    entropy_loss       | -21.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6199      |
# |    policy_loss        | -103      |
# |    reward             | 0.4558191 |
# |    std                | 1.05      |
# |    value_loss         | 55.1      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 6300      |
# |    time_elapsed       | 120       |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -21.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | 55.6      |
# |    reward             | 1.0596557 |
# |    std                | 1.05      |
# |    value_loss         | 9.77      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 261        |
# |    iterations         | 6400       |
# |    time_elapsed       | 122        |
# |    total_timesteps    | 32000      |
# | train/                |            |
# |    entropy_loss       | -21.9      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6399       |
# |    policy_loss        | -167       |
# |    reward             | -1.5593375 |
# |    std                | 1.05       |
# |    value_loss         | 74.5       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 261         |
# |    iterations         | 6500        |
# |    time_elapsed       | 124         |
# |    total_timesteps    | 32500       |
# | train/                |             |
# |    entropy_loss       | -21.9       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6499        |
# |    policy_loss        | 112         |
# |    reward             | -0.39394948 |
# |    std                | 1.05        |
# |    value_loss         | 32.8        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 261         |
# |    iterations         | 6600        |
# |    time_elapsed       | 126         |
# |    total_timesteps    | 33000       |
# | train/                |             |
# |    entropy_loss       | -21.9       |
# |    explained_variance | 0.0728      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6599        |
# |    policy_loss        | -12.6       |
# |    reward             | 0.098300494 |
# |    std                | 1.05        |
# |    value_loss         | 2.35        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 6700      |
# |    time_elapsed       | 127       |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -21.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | -244      |
# |    reward             | -3.099573 |
# |    std                | 1.04      |
# |    value_loss         | 125       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 6800      |
# |    time_elapsed       | 129       |
# |    total_timesteps    | 34000     |
# | train/                |           |
# |    entropy_loss       | -21.9     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6799      |
# |    policy_loss        | -296      |
# |    reward             | 3.083243  |
# |    std                | 1.05      |
# |    value_loss         | 233       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 261        |
# |    iterations         | 6900       |
# |    time_elapsed       | 131        |
# |    total_timesteps    | 34500      |
# | train/                |            |
# |    entropy_loss       | -22        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6899       |
# |    policy_loss        | 106        |
# |    reward             | -2.6970663 |
# |    std                | 1.05       |
# |    value_loss         | 28.6       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 7000     |
# |    time_elapsed       | 133      |
# |    total_timesteps    | 35000    |
# | train/                |          |
# |    entropy_loss       | -22      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 6999     |
# |    policy_loss        | 238      |
# |    reward             | -8.9874  |
# |    std                | 1.05     |
# |    value_loss         | 150      |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 261         |
# |    iterations         | 7100        |
# |    time_elapsed       | 135         |
# |    total_timesteps    | 35500       |
# | train/                |             |
# |    entropy_loss       | -22         |
# |    explained_variance | -0.0146     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 7099        |
# |    policy_loss        | -94.6       |
# |    reward             | -0.38072026 |
# |    std                | 1.05        |
# |    value_loss         | 21.1        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 7200      |
# |    time_elapsed       | 137       |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -22       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -377      |
# |    reward             | 1.3337369 |
# |    std                | 1.05      |
# |    value_loss         | 300       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 7300      |
# |    time_elapsed       | 139       |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -21.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | 389       |
# |    reward             | -0.341072 |
# |    std                | 1.05      |
# |    value_loss         | 663       |
# -------------------------------------
# day: 1217, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 9050033.55
# total_reward: 8050033.55
# total_cost: 6092.85
# total_trades: 6486
# Sharpe: 1.490
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 7400      |
# |    time_elapsed       | 141       |
# |    total_timesteps    | 37000     |
# | train/                |           |
# |    entropy_loss       | -22       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7399      |
# |    policy_loss        | 120       |
# |    reward             | -6.014884 |
# |    std                | 1.05      |
# |    value_loss         | 55.4      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 261        |
# |    iterations         | 7500       |
# |    time_elapsed       | 143        |
# |    total_timesteps    | 37500      |
# | train/                |            |
# |    entropy_loss       | -22        |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7499       |
# |    policy_loss        | -13.5      |
# |    reward             | -6.0592175 |
# |    std                | 1.05       |
# |    value_loss         | 46.9       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 261          |
# |    iterations         | 7600         |
# |    time_elapsed       | 145          |
# |    total_timesteps    | 38000        |
# | train/                |              |
# |    entropy_loss       | -22          |
# |    explained_variance | 0.0823       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 7599         |
# ...
# |    iterations           | 14          |
# |    time_elapsed         | 94          |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.005317791 |
# |    clip_fraction        | 0.0155      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -21.4       |
# |    explained_variance   | -0.0059     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 37          |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.00769    |
# |    reward               | 0.45292556  |
# |    std                  | 1.01        |
# |    value_loss           | 71.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 304          |
# |    iterations           | 15           |
# |    time_elapsed         | 100          |
# |    total_timesteps      | 30720        |
# | train/                  |              |
# |    approx_kl            | 0.0057209614 |
# |    clip_fraction        | 0.0153       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -21.4        |
# |    explained_variance   | -0.00291     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 33.1         |
# |    n_updates            | 140          |
# |    policy_gradient_loss | -0.0056      |
# |    reward               | 0.13036229   |
# |    std                  | 1.01         |
# |    value_loss           | 62.7         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 304        |
# |    iterations           | 16         |
# |    time_elapsed         | 107        |
# |    total_timesteps      | 32768      |
# | train/                  |            |
# |    approx_kl            | 0.00473603 |
# |    clip_fraction        | 0.00728    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -21.4      |
# |    explained_variance   | 0.0135     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 36.5       |
# |    n_updates            | 150        |
# |    policy_gradient_loss | -0.0056    |
# |    reward               | -1.3391659 |
# |    std                  | 1.01       |
# |    value_loss           | 73.9       |
# ----------------------------------------
# day: 1532, episode: 55
# begin_total_asset: 1000000.00
# end_total_asset: 1606795.88
# total_reward: 606795.88
# total_cost: 53664.17
# total_trades: 22143
# Sharpe: 0.445
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 17          |
# |    time_elapsed         | 114         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.008759091 |
# |    clip_fraction        | 0.0341      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -21.4       |
# |    explained_variance   | -0.0179     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 21.7        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.00755    |
# |    reward               | -0.7607104  |
# |    std                  | 1.01        |
# |    value_loss           | 46.1        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 304          |
# |    iterations           | 18           |
# |    time_elapsed         | 120          |
# |    total_timesteps      | 36864        |
# | train/                  |              |
# |    approx_kl            | 0.0092780925 |
# |    clip_fraction        | 0.0448       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -21.4        |
# |    explained_variance   | -0.00125     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 26.2         |
# |    n_updates            | 170          |
# |    policy_gradient_loss | -0.00856     |
# |    reward               | 0.2897418    |
# |    std                  | 1.01         |
# |    value_loss           | 51.1         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 305          |
# |    iterations           | 19           |
# |    time_elapsed         | 127          |
# |    total_timesteps      | 38912        |
# | train/                  |              |
# |    approx_kl            | 0.0069204024 |
# |    clip_fraction        | 0.0236       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -21.5        |
# |    explained_variance   | 0.000583     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 57.1         |
# |    n_updates            | 180          |
# |    policy_gradient_loss | -0.00664     |
# |    reward               | -1.7271099   |
# |    std                  | 1.01         |
# |    value_loss           | 113          |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 305         |
# |    iterations           | 20          |
# |    time_elapsed         | 134         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.010159606 |
# |    clip_fraction        | 0.0623      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -21.5       |
# |    explained_variance   | 0.00257     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 24.7        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0122     |
# |    reward               | -2.4402506  |
# |    std                  | 1.01        |
# |    value_loss           | 52.5        |
# -----------------------------------------
# day: 1532, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 2238058.05
# total_reward: 1238058.05
# total_cost: 53728.31
# total_trades: 22315
# Sharpe: 0.663
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 304          |
# |    iterations           | 21           |
# |    time_elapsed         | 141          |
# |    total_timesteps      | 43008        |
# | train/                  |              |
# |    approx_kl            | 0.01035609   |
# |    clip_fraction        | 0.052        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -21.5        |
# |    explained_variance   | -0.00826     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 39           |
# |    n_updates            | 200          |
# |    policy_gradient_loss | -0.00971     |
# |    reward               | -0.006762955 |
# |    std                  | 1.01         |
# |    value_loss           | 76.9         |
# ------------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 304        |
# |    iterations           | 22         |
# |    time_elapsed         | 147        |
# |    total_timesteps      | 45056      |
# | train/                  |            |
# |    approx_kl            | 0.00451966 |
# |    clip_fraction        | 0.00796    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -21.5      |
# |    explained_variance   | 0.0155     |
# |    learning_rate        | 0.00025    |
# |    loss                 | 57.6       |
# |    n_updates            | 210        |
# |    policy_gradient_loss | -0.00482   |
# |    reward               | 0.44732052 |
# |    std                  | 1.01       |
# |    value_loss           | 106        |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 304         |
# |    iterations           | 23          |
# |    time_elapsed         | 154         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.005720593 |
# |    clip_fraction        | 0.0145      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -21.5       |
# |    explained_variance   | -0.00512    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 32.2        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.00627    |
# |    reward               | 0.33347616  |
# |    std                  | 1.01        |
# |    value_loss           | 64          |
# -----------------------------------------
# day: 1532, episode: 65
# begin_total_asset: 1000000.00
# end_total_asset: 2410413.78
# total_reward: 1410413.78
# total_cost: 54853.72
# total_trades: 22335
# Sharpe: 0.711
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 304          |
# |    iterations           | 24           |
# |    time_elapsed         | 161          |
# |    total_timesteps      | 49152        |
# | train/                  |              |
# |    approx_kl            | 0.0114753395 |
# |    clip_fraction        | 0.0739       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -21.5        |
# |    explained_variance   | -0.00409     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 19.9         |
# |    n_updates            | 230          |
# |    policy_gradient_loss | -0.0125      |
# |    reward               | 0.002858374  |
# |    std                  | 1.02         |
# |    value_loss           | 38.2         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 305          |
# |    iterations           | 25           |
# |    time_elapsed         | 167          |
# |    total_timesteps      | 51200        |
# | train/                  |              |
# |    approx_kl            | 0.0036496818 |
# |    clip_fraction        | 0.00854      |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -21.5        |
# |    explained_variance   | 0.00218      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 69.1         |
# |    n_updates            | 240          |
# |    policy_gradient_loss | -0.00521     |
# |    reward               | 1.3126725    |
# |    std                  | 1.02         |
# |    value_loss           | 124          |
# ------------------------------------------
# ======PPO Validation from:  2022-04-25 to  2022-07-27
# PPO Sharpe Ratio:  0.31411260834216664
# ======DDPG Training========
# {'buffer_size': 50000, 'learning_rate': 0.001, 'batch_size': 512}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_441_1
# day: 1532, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 1463957.12
# total_reward: 463957.12
# total_cost: 1855.06
# total_trades: 9370
# Sharpe: 0.379
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 133      |
# |    time_elapsed    | 45       |
# |    total_timesteps | 6132     |
# | train/             |          |
# |    actor_loss      | 455      |
# |    critic_loss     | 2.95e+03 |
# |    learning_rate   | 0.001    |
# |    n_updates       | 4599     |
# |    reward          | 0.37588  |
# ---------------------------------
# day: 1532, episode: 75
# begin_total_asset: 1000000.00
# end_total_asset: 1463957.12
# total_reward: 463957.12
# total_cost: 1855.06
# total_trades: 9370
# Sharpe: 0.379
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 119      |
# |    time_elapsed    | 102      |
# |    total_timesteps | 12264    |
# | train/             |          |
# |    actor_loss      | 265      |
# |    critic_loss     | 95.2     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 10731    |
# |    reward          | 0.37588  |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 116      |
# |    time_elapsed    | 157      |
# |    total_timesteps | 18396    |
# | train/             |          |
# |    actor_loss      | 170      |
# |    critic_loss     | 96.9     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 16863    |
# |    reward          | 0.37588  |
# ---------------------------------
# day: 1532, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 1463957.12
# total_reward: 463957.12
# total_cost: 1855.06
# total_trades: 9370
# Sharpe: 0.379
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 16       |
# |    fps             | 114      |
# |    time_elapsed    | 213      |
# |    total_timesteps | 24528    |
# | train/             |          |
# |    actor_loss      | 124      |
# |    critic_loss     | 10.1     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 22995    |
# |    reward          | 0.37588  |
# ---------------------------------
# day: 1532, episode: 85
# begin_total_asset: 1000000.00
# end_total_asset: 1463957.12
# total_reward: 463957.12
# total_cost: 1855.06
# total_trades: 9370
# Sharpe: 0.379
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 114      |
# |    time_elapsed    | 267      |
# |    total_timesteps | 30660    |
# | train/             |          |
# |    actor_loss      | 89.5     |
# |    critic_loss     | 2.23     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 29127    |
# |    reward          | 0.37588  |
# ---------------------------------
# day: 1532, episode: 90
# begin_total_asset: 1000000.00
# end_total_asset: 1463957.12
# total_reward: 463957.12
# total_cost: 1855.06
# total_trades: 9370
# Sharpe: 0.379
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 24       |
# |    fps             | 114      |
# |    time_elapsed    | 320      |
# |    total_timesteps | 36792    |
# | train/             |          |
# |    actor_loss      | 63.6     |
# |    critic_loss     | 1.15     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 35259    |
# |    reward          | 0.37588  |
# ---------------------------------
# day: 1532, episode: 95
# begin_total_asset: 1000000.00
# end_total_asset: 1463957.12
# total_reward: 463957.12
# total_cost: 1855.06
# total_trades: 9370
# Sharpe: 0.379
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 28       |
# |    fps             | 113      |
# |    time_elapsed    | 376      |
# |    total_timesteps | 42924    |
# | train/             |          |
# |    actor_loss      | 44.9     |
# |    critic_loss     | 0.716    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 41391    |
# |    reward          | 0.37588  |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 32       |
# |    fps             | 113      |
# |    time_elapsed    | 432      |
# |    total_timesteps | 49056    |
# | train/             |          |
# |    actor_loss      | 31.5     |
# |    critic_loss     | 0.546    |
# |    learning_rate   | 0.001    |
# |    n_updates       | 47523    |
# |    reward          | 0.37588  |
# ---------------------------------
# day: 1532, episode: 100
# begin_total_asset: 1000000.00
# end_total_asset: 1463957.12
# total_reward: 463957.12
# total_cost: 1855.06
# total_trades: 9370
# Sharpe: 0.379
# =================================
# ======DDPG Validation from:  2022-04-25 to  2022-07-27
# ======Best Model Retraining from:  2016-01-01 to  2022-07-27
# ======Trading from:  2022-07-27 to  2022-11-01
# Ensemble Strategy took:  81.51978379090627  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-09       DDPG  -0.309903  -0.231408   -0.211742
# 1  189  2021-04-09  2021-07-13        A2C   0.526404   0.281354    0.338652
# 2  252  2021-07-13  2021-10-19       DDPG  -0.035964  -0.242834   -0.029753
# 3  315  2021-10-19  2022-01-17        A2C  -0.142092  -0.244312   -0.149271
# 4  378  2022-01-17  2022-04-25        A2C  -0.173878  -0.189487   -0.384488
# 5  441  2022-04-25  2022-07-27        PPO   0.281574   0.314113    0.091099

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()
print(unique_trade_date.shape)
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# %matplotlib inline
df_account_value['date'] = pd.to_datetime(df_account_value['date'])
df_account_value.plot(x='date',y='account_value',legend=False)
plt.xlabel('Date')
plt.ylabel('Account Value')
# df_account_value.account_value.plot(xlabel='Date',ylabel='Account Value')
# set name of x axis: Date
# Out:
# (485,)
# Sharpe Ratio:  -0.22559652333340768
# Text(0, 0.5, 'Account Value')

# %%
new_end_date = '2022-01-01'
df_account_value = df_account_value[df_account_value['date'] <= new_end_date]

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return          0.223226
# Cumulative returns     0.154795
# Annual volatility      0.279093
# Sharpe ratio           0.865016
# Calmar ratio           1.671271
# Stability              0.229290
# Max drawdown          -0.133567
# Omega ratio            1.152581
# Sortino ratio          1.265286
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.006754
# Daily value at risk   -0.034204
# dtype: float64

# %%
print("==============Get Baseline Stats===========")
baseline_df = pd.read_csv('datasets/csi300.csv')
baseline_df = baseline_df[baseline_df['date'] <= new_end_date]
stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# Annual return          0.062881
# Cumulative returns     0.424122
# Annual volatility      0.194388
# Sharpe ratio           0.411575
# Calmar ratio           0.193706
# Stability              0.699828
# Max drawdown          -0.324620
# Omega ratio            1.076868
# Sortino ratio          0.566911
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.052678
# Daily value at risk   -0.024173
# dtype: float64

# %%
print("==============Compare to SSE 50 Index===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = 'CSI300', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'], baseline_df = baseline_df)
# Out:
# ==============Compare to SSE 50 Index===========
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-09</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-12-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>8</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>22.323%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>15.479%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>27.909%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.87</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>1.67</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.23</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-13.357%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.15</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.27</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.01</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.42%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.30</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>1.38</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>13.36</td>
#       <td>2021-06-28</td>
#       <td>2021-09-22</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6.13</td>
#       <td>2021-04-29</td>
#       <td>2021-05-10</td>
#       <td>2021-05-17</td>
#       <td>13</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.56</td>
#       <td>2021-06-10</td>
#       <td>2021-06-16</td>
#       <td>2021-06-25</td>
#       <td>12</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2.34</td>
#       <td>2021-06-01</td>
#       <td>2021-06-08</td>
#       <td>2021-06-10</td>
#       <td>8</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>1.23</td>
#       <td>2021-04-23</td>
#       <td>2021-04-26</td>
#       <td>2021-04-28</td>
#       <td>4</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.10%</td>
#       <td>-5.23%</td>
#       <td>6.32%</td>
#     </tr>
#   </tbody>
# </table>

# %%
total_return_rate
# Out:
# 0.10222773167000065

# %%
len(df_account_value)
# Out:
# 189

# %%
# 计算年化收益率

total_return_rate = df_account_value.account_value.values[-1] / 1e6  - 1
annual_return_rate = (1 + total_return_rate) ** (250 / len(df_account_value)) - 1
print('年化收益率：', annual_return_rate)
# Out:
# 年化收益率： 0.13740324337855592

# %%
df_account_value.head(10)
# Out:
#    account_value       date  daily_return    datadate
# 0   1.000000e+06 2020-11-06           NaN  2020-11-06
# 1   1.003903e+06 2020-11-09      0.003903  2020-11-09
# 2   1.003663e+06 2020-11-10     -0.000239  2020-11-10
# 3   1.002640e+06 2020-11-11     -0.001020  2020-11-11
# 4   1.002187e+06 2020-11-12     -0.000452  2020-11-12
# 5   1.001421e+06 2020-11-13     -0.000764  2020-11-13
# 6   1.001776e+06 2020-11-16      0.000354  2020-11-16
# 7   1.000769e+06 2020-11-17     -0.001006  2020-11-17
# 8   9.994531e+05 2020-11-18     -0.001314  2020-11-18
# 9   1.003087e+06 2020-11-19      0.003636  2020-11-19

# %%
# 分别画出 processed 数据中每只股票的close的折线图
for i in range(len(ticket_list)):
    plt.plot(processed[processed.tic == ticket_list[i]].date, processed[processed.tic == ticket_list[i]].close)
plt.legend(ticket_list)

# %%
# 画出 processed 数据中每只股票的close的平均值的折线图，每个date只画一次
processed_mean = processed.groupby('date').mean()
processed_mean['date'] = pd.to_datetime(processed_mean.index)
plt.plot(processed_mean.date, processed_mean.close)

# %%
processed.groupby('date')

# %%
# 计算股票在每个date的体量百分比和所有股票体量的加权和



# processed['volume_pct'] = processed.groupby('date')['volume'].apply(lambda x: x / x.sum())

# plot processed 数据中的close按照股票体量的加权和 区分训练集和测试集，每个date只画一次
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1567, in GroupBy.apply(self, func, *args, **kwargs)
#    1564     with rewrite_warning(
#    1565         old_msg, FutureWarning, new_msg
#    1566     ) if is_np_func else nullcontext():
# -> 1567         result = self._python_apply_general(f, self._selected_obj)
#    1568 except TypeError:
#    1569     # gh-20949
#    1570     # try again, with .apply acting as a filtering
#    (...)
#    1574     # fails on *some* columns, e.g. a numeric operation
#    1575     # on a string grouper column
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1629, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1601 """
#    1602 Apply function f in python space
#    1603
#    (...)
#    1627     data after applying f
#    1628 """
# -> 1629 values, mutated = self.grouper.apply(f, data, self.axis)
#    1630 if not_indexed_same is None:
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/groupby/ops.py:839, in BaseGrouper.apply(self, f, data, axis)
#     838 group_axes = group.axes
# --> 839 res = f(group)
#     840 if not mutated and not _is_indexed_like(res, group_axes, axis):
#
# Cell In[51], line 5, in <lambda>(x)
#       4 # plot processed 数据中的close按照股票体量的加权和 区分训练集和测试集，每个date只画一次
# ----> 5 plt.plot(processed[processed.date <= TRAIN_END_DATE].groupby('date')['close'].apply(lambda x: np.average(x, weights=processed[processed.date <= TRAIN_END_DATE].groupby('date')['volume'].apply(lambda x: x / x.sum()))), label='train')
#       6 plt.plot(processed[processed.date > TRAIN_END_DATE].groupby('date')['close'].apply(lambda x: np.average(x, weights=processed[processed.date > TRAIN_END_DATE].groupby('date')['volume'].apply(lambda x: x / x.sum()))), label='test')
#
# File <__array_function__ internals>:200, in average(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:532, in average(a, axis, weights, returned, keepdims)
#     531 if axis is None:
# --> 532     raise TypeError(
#     533         "Axis must be specified when shapes of a and weights "
#     534         "differ.")
#     535 if wgt.ndim != 1:
#
# TypeError: Axis must be specified when shapes of a and weights differ.
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 5
#       2 processed['volume_pct'] = processed.groupby('date')['volume'].apply(lambda x: x / x.sum())
#       4 # plot processed 数据中的close按照股票体量的加权和 区分训练集和测试集，每个date只画一次
# ----> 5 plt.plot(processed[processed.date <= TRAIN_END_DATE].groupby('date')['close'].apply(lambda x: np.average(x, weights=processed[processed.date <= TRAIN_END_DATE].groupby('date')['volume'].apply(lambda x: x / x.sum()))), label='train')
#       6 plt.plot(processed[processed.date > TRAIN_END_DATE].groupby('date')['close'].apply(lambda x: np.average(x, weights=processed[processed.date > TRAIN_END_DATE].groupby('date')['volume'].apply(lambda x: x / x.sum()))), label='test')
#       7 plt.legend()
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/groupby/generic.py:254, in SeriesGroupBy.apply(self, func, *args, **kwargs)
#     248 @Appender(
#     249     _apply_docs["template"].format(
#     250         input="series", examples=_apply_docs["series_examples"]
#     251     )
#     252 )
#     253 def apply(self, func, *args, **kwargs) -> Series:
# --> 254     return super().apply(func, *args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1588, in GroupBy.apply(self, func, *args, **kwargs)
#    1580             new_msg = (
#    1581                 f"The operation {orig_func} failed on a column. If any error "
#    1582                 f"is raised, this will raise an exception in a future version "
#    1583                 f"of pandas. Drop these columns to avoid this warning."
#    1584             )
#    1585             with rewrite_warning(
#    1586                 old_msg, FutureWarning, new_msg
#    1587             ) if is_np_func else nullcontext():
# -> 1588                 return self._python_apply_general(f, self._selected_obj)
#    1590 return result
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1629, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1592 @final
#    1593 def _python_apply_general(
#    1594     self,
#    (...)
#    1599     is_agg: bool = False,
#    1600 ) -> NDFrameT:
#    1601     """
#    1602     Apply function f in python space
#    1603
#    (...)
#    1627         data after applying f
#    1628     """
# -> 1629     values, mutated = self.grouper.apply(f, data, self.axis)
#    1630     if not_indexed_same is None:
#    1631         not_indexed_same = mutated or self.mutated
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/groupby/ops.py:839, in BaseGrouper.apply(self, f, data, axis)
#     837 # group might be modified
#     838 group_axes = group.axes
# --> 839 res = f(group)
#     840 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     841     mutated = True
#
# Cell In[51], line 5, in <lambda>(x)
#       2 processed['volume_pct'] = processed.groupby('date')['volume'].apply(lambda x: x / x.sum())
#       4 # plot processed 数据中的close按照股票体量的加权和 区分训练集和测试集，每个date只画一次
# ----> 5 plt.plot(processed[processed.date <= TRAIN_END_DATE].groupby('date')['close'].apply(lambda x: np.average(x, weights=processed[processed.date <= TRAIN_END_DATE].groupby('date')['volume'].apply(lambda x: x / x.sum()))), label='train')
#       6 plt.plot(processed[processed.date > TRAIN_END_DATE].groupby('date')['close'].apply(lambda x: np.average(x, weights=processed[processed.date > TRAIN_END_DATE].groupby('date')['volume'].apply(lambda x: x / x.sum()))), label='test')
#       7 plt.legend()
#
# File <__array_function__ internals>:200, in average(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:532, in average(a, axis, weights, returned, keepdims)
#     530 if a.shape != wgt.shape:
#     531     if axis is None:
# --> 532         raise TypeError(
#     533             "Axis must be specified when shapes of a and weights "
#     534             "differ.")
#     535     if wgt.ndim != 1:
#     536         raise TypeError(
#     537             "1D weights expected when shapes of a and weights differ.")
#
# TypeError: Axis must be specified when shapes of a and weights differ.

# %%
# plot baseline_df 数据中的close 区分训练集和测试集
plt.plot(baseline_df[baseline_df.date <= TRAIN_END_DATE].date, baseline_df[baseline_df.date <= TRAIN_END_DATE].close)
plt.plot(baseline_df[(baseline_df.date > TRAIN_END_DATE) & (baseline_df.date <= TEST_END_DATE)].date, baseline_df[(baseline_df.date > TRAIN_END_DATE) & (baseline_df.date <= TEST_END_DATE)].close)
plt.plot(baseline_df[baseline_df.date > TEST_END_DATE].date, baseline_df[baseline_df.date > TEST_END_DATE].close)
plt.legend(['train period', 'test period', 'validation period'])
plt.title('SSE 50 Index (benchmark, not for training)')
plt.savefig('outputs/SSE50IndexStock0308/SSE50Index.png')
plt.xlabel('Date')
# Out:
# Text(0.5, 23.52222222222222, 'Date')

# %%
processed.columns
# Out:
# Index(['tic', 'date', 'open', 'high', 'low', 'close', 'volume', 'day', 'macd',
#        'boll_ub', 'boll_lb', 'rsi_30', 'cci_30', 'dx_30', 'close_30_sma',
#        'close_60_sma', 'turbulence', 'turnover_rate', 'pb'],
#       dtype='object')
