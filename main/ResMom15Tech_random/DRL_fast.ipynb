# %%
import warnings
warnings.filterwarnings("ignore")
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.config_tickers import DOW_30_TICKER
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools

# %%
# select stocks
res_mom = pd.read_csv('../../PB_ROE/res_mom.csv')
# last 15 stocks
res_mom_15 = res_mom.tail(15)
# to list
res_mom_15_list = res_mom_15['ts_code'].to_list()
res_mom_15_list
# Out:
# ['601398.SH',
#  '600031.SH',
#  '601800.SH',
#  '002241.SZ',
#  '601328.SH',
#  '601318.SH',
#  '600085.SH',
#  '601186.SH',
#  '600519.SH',
#  '601668.SH',
#  '601888.SH',
#  '601225.SH',
#  '600585.SH',
#  '000069.SZ',
#  '002007.SZ']

# %%
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])
# TRAIN_START_DATE = '2010-01-01'
# TRAIN_END_DATE = '2020-01-01'
# TEST_START_DATE = '2020-01-01'
# TEST_END_DATE = '2023-01-01'
# processed = pd.read_csv('datasets/SSE_processed.csv')
TRAIN_START_DATE='2016-01-01'
TRAIN_END_DATE='2021-01-01'
TEST_START_DATE='2021-01-01'
# TEST_END_DATE='2023-01-01'
TEST_END_DATE='2023-01-01'


processed = pd.read_csv('datasets/processed_technical_indicators.csv')
ticket_list = res_mom_15_list
processed = processed[processed['tic'].isin(ticket_list)]
# sort
print(processed.shape)
# processed.sample(5)
processed.tic.value_counts()
# Out:
# (25545, 17)
# 000069.SZ    1703
# 002007.SZ    1703
# 002241.SZ    1703
# 600031.SH    1703
# 600085.SH    1703
# 600519.SH    1703
# 600585.SH    1703
# 601186.SH    1703
# 601225.SH    1703
# 601318.SH    1703
# 601328.SH    1703
# 601398.SH    1703
# 601668.SH    1703
# 601800.SH    1703
# 601888.SH    1703
# Name: tic, dtype: int64

# %%
print(processed.columns)
print(INDICATORS)
# Out:
# Index(['date', 'tic', 'open', 'high', 'low', 'close', 'volume', 'day', 'macd',
#        'boll_ub', 'boll_lb', 'rsi_30', 'cci_30', 'dx_30', 'close_30_sma',
#        'close_60_sma', 'turbulence'],
#       dtype='object')
# ['macd', 'boll_ub', 'boll_lb', 'rsi_30', 'cci_30', 'dx_30', 'close_30_sma', 'close_60_sma']

# %%
INDICATORS.append('turnover_rate')
INDICATORS.append('pb')
INDICATORS.append('day')
INDICATORS.append('close')
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
# 重新import DRLEnsembleAgent
import importlib
# from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
importlib.reload(sys.modules['finrl.agents.stablebaselines3.models'])
from finrl.agents.stablebaselines3.models import DRLAgent,DRLEnsembleAgent

# %%
stock_dimension = len(processed.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
env_kwargs = {
    "hmax": 100, 
    "initial_amount": 1000000, 
    "buy_cost_pct": 0.001, 
    "sell_cost_pct": 0.001, 
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4,
    "print_verbosity":5    
}

rebalance_window = 63 # rebalance_window is the number of days to retrain the model
validation_window = 63 # validation_window is the number of days to do validation and trading (e.g. if validation_window=63, then both validation and trading period will be 63 days)

ensemble_agent = DRLEnsembleAgent(df=processed,
                 train_period=(TRAIN_START_DATE,TRAIN_END_DATE),
                 val_test_period=(TEST_START_DATE,TEST_END_DATE),
                 rebalance_window=rebalance_window, 
                 validation_window=validation_window, 
                 **env_kwargs)

A2C_model_kwargs = {
                    'n_steps': 5,
                    'ent_coef': 0.005,
                    'learning_rate': 0.0007
                    }

PPO_model_kwargs = {
                    "ent_coef":0.01,
                    "n_steps": 2048,
                    "learning_rate": 0.00025,
                    # "batch_size": 128
                    "batch_size": 512
                    }

DDPG_model_kwargs = {
                      #"action_noise":"ornstein_uhlenbeck",
                      "buffer_size": 10_000,
                      "learning_rate": 0.0005,
                      # "batch_size": 64
                      "batch_size": 512
                    }

timesteps_dict = {'a2c' : 10_000, 
                 'ppo' : 10_000, 
                 'ddpg' : 10_000
                 }
# Out:
# Stock Dimension: 15, State Space: 151

# %%
df_summary = ensemble_agent.run_ensemble_strategy(A2C_model_kwargs,
                                                 PPO_model_kwargs,
                                                 DDPG_model_kwargs,
                                                 timesteps_dict)
# Out:
# ============Start Ensemble Strategy============
# ============================================
# turbulence_threshold:  375.90577053030336
# ======Model training from:  2016-01-01 to  2021-01-04
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_126_1
# -------------------------------------
# | time/                 |           |
# |    fps                | 214       |
# |    iterations         | 100       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -21.3     |
# |    explained_variance | 0.0546    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | -15.8     |
# |    reward             | 4.0745664 |
# |    std                | 1         |
# |    value_loss         | 2.29      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 239        |
# |    iterations         | 200        |
# |    time_elapsed       | 4          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -21.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | 0.346      |
# |    reward             | 0.74053234 |
# |    std                | 1.01       |
# |    value_loss         | 9.48       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 248       |
# |    iterations         | 300       |
# |    time_elapsed       | 6         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -21.4     |
# |    explained_variance | -0.00541  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | 4.19      |
# |    reward             | -0.615269 |
# |    std                | 1         |
# |    value_loss         | 1.8       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 253        |
# |    iterations         | 400        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 2000       |
# | train/                |            |
# |    entropy_loss       | -21.4      |
# |    explained_variance | 0.0377     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | 113        |
# |    reward             | -1.5004799 |
# |    std                | 1          |
# |    value_loss         | 29.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 257        |
# |    iterations         | 500        |
# |    time_elapsed       | 9          |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -21.3      |
# |    explained_variance | -0.0724    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -7.86      |
# |    reward             | -1.1526892 |
# |    std                | 1          |
# |    value_loss         | 0.288      |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 260      |
# |    iterations         | 600      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -21.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -33.5    |
# |    reward             | -5.42028 |
# |    std                | 1        |
# |    value_loss         | 20.2     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 700      |
# |    time_elapsed       | 13       |
# |    total_timesteps    | 3500     |
# | train/                |          |
# |    entropy_loss       | -21.3    |
# |    explained_variance | 5.96e-08 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 699      |
# |    policy_loss        | 134      |
# |    reward             | 1.743469 |
# |    std                | 1        |
# |    value_loss         | 54.9     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 264      |
# |    iterations         | 800      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -21.3    |
# |    explained_variance | 0.0024   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | -6.3     |
# |    reward             | 1.719699 |
# |    std                | 1        |
# |    value_loss         | 1.97     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 265       |
# |    iterations         | 900       |
# |    time_elapsed       | 16        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -21.3     |
# |    explained_variance | 1.04e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | 147       |
# |    reward             | -1.121898 |
# |    std                | 1         |
# |    value_loss         | 47.3      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 265        |
# |    iterations         | 1000       |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -21.3      |
# |    explained_variance | -0.00753   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 148        |
# |    reward             | -2.3395567 |
# |    std                | 1          |
# |    value_loss         | 55         |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 266      |
# |    iterations         | 1100     |
# |    time_elapsed       | 20       |
# |    total_timesteps    | 5500     |
# | train/                |          |
# |    entropy_loss       | -21.3    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1099     |
# |    policy_loss        | 49.2     |
# |    reward             | 2.34651  |
# |    std                | 1        |
# |    value_loss         | 5.76     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 267       |
# |    iterations         | 1200      |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -21.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -12.4     |
# |    reward             | -6.341513 |
# |    std                | 1         |
# |    value_loss         | 2.57      |
# -------------------------------------
# day: 1217, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 6289980.69
# total_reward: 5289980.69
# total_cost: 4601.49
# total_trades: 9858
# Sharpe: 1.466
# =================================
# -------------------------------------
# | time/                 |           |
# |    fps                | 268       |
# |    iterations         | 1300      |
# |    time_elapsed       | 24        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -21.4     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | 7.87      |
# |    reward             | -1.640435 |
# |    std                | 1         |
# |    value_loss         | 0.286     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 268       |
# |    iterations         | 1400      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -21.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 297       |
# |    reward             | -3.144606 |
# |    std                | 1         |
# |    value_loss         | 216       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 268      |
# |    iterations         | 1500     |
# |    time_elapsed       | 27       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -21.3    |
# |    explained_variance | -0.0213  |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 13.6     |
# |    reward             | 0.296142 |
# |    std                | 1        |
# |    value_loss         | 4.69     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 269       |
# |    iterations         | 1600      |
# |    time_elapsed       | 29        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -21.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -565      |
# |    reward             | -2.947019 |
# |    std                | 1.01      |
# |    value_loss         | 790       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 269       |
# |    iterations         | 1700      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -21.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 2.4       |
# |    reward             | 2.0805802 |
# |    std                | 1         |
# |    value_loss         | 27.7      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 269       |
# |    iterations         | 1800      |
# |    time_elapsed       | 33        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -21.4     |
# |    explained_variance | 0.0106    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -25.4     |
# |    reward             | -0.333021 |
# |    std                | 1.01      |
# |    value_loss         | 9.87      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 270        |
# |    iterations         | 1900       |
# |    time_elapsed       | 35         |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -21.4      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | -74.6      |
# |    reward             | -0.4996778 |
# |    std                | 1.01       |
# |    value_loss         | 23         |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 270         |
# |    iterations         | 2000        |
# |    time_elapsed       | 36          |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -21.4       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | -27.3       |
# |    reward             | -0.18461634 |
# |    std                | 1.01        |
# |    value_loss         | 2.03        |
# ---------------------------------------
# ======A2C Validation from:  2021-01-04 to  2021-04-09
# A2C Sharpe Ratio:  0.012351850219747497
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 512}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_126_1
# day: 1217, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 2606142.91
# total_reward: 1606142.91
# total_cost: 77291.61
# total_trades: 17803
# Sharpe: 1.260
# =================================
# ------------------------------------
# | time/              |             |
# |    fps             | 369         |
# |    iterations      | 1           |
# |    time_elapsed    | 5           |
# |    total_timesteps | 2048        |
# | train/             |             |
# |    reward          | 0.053067237 |
# ------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 357          |
# |    iterations           | 2            |
# |    time_elapsed         | 11           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0061100377 |
# |    clip_fraction        | 0.0779       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -21.3        |
# |    explained_variance   | -0.00767     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 12.2         |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00772     |
# |    reward               | 3.7608209    |
# |    std                  | 1            |
# |    value_loss           | 29.6         |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 354          |
# |    iterations           | 3            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 6144         |
# | train/                  |              |
# |    approx_kl            | 0.0046917396 |
# |    clip_fraction        | 0.0145       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -21.3        |
# |    explained_variance   | -0.00483     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 43.7         |
# |    n_updates            | 20           |
# |    policy_gradient_loss | -0.00236     |
# |    reward               | 0.112341695  |
# |    std                  | 1            |
# |    value_loss           | 117          |
# ------------------------------------------
# day: 1217, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 4878951.85
# total_reward: 3878951.85
# total_cost: 79005.12
# total_trades: 17866
# Sharpe: 1.715
# =================================
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 353          |
# |    iterations           | 4            |
# |    time_elapsed         | 23           |
# |    total_timesteps      | 8192         |
# | train/                  |              |
# |    approx_kl            | 0.0072713853 |
# |    clip_fraction        | 0.0679       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -21.3        |
# |    explained_variance   | -0.0221      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 23.4         |
# |    n_updates            | 30           |
# |    policy_gradient_loss | -0.00844     |
# |    reward               | 0.57140744   |
# |    std                  | 1            |
# |    value_loss           | 51           |
# ------------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 351          |
# |    iterations           | 5            |
# |    time_elapsed         | 29           |
# |    total_timesteps      | 10240        |
# | train/                  |              |
# |    approx_kl            | 0.0093655195 |
# |    clip_fraction        | 0.0465       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -21.4        |
# |    explained_variance   | -0.0164      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 60.1         |
# |    n_updates            | 40           |
# |    policy_gradient_loss | -0.00655     |
# |    reward               | 1.5121157    |
# |    std                  | 1            |
# |    value_loss           | 107          |
# ------------------------------------------
# ======PPO Validation from:  2021-01-04 to  2021-04-09
# PPO Sharpe Ratio:  0.014776228365273602
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 512}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_126_1
# day: 1217, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 5297617.83
# total_reward: 4297617.83
# total_cost: 1022.29
# total_trades: 11791
# Sharpe: 1.360
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 139       |
# |    time_elapsed    | 34        |
# |    total_timesteps | 4872      |
# | train/             |           |
# |    actor_loss      | -653      |
# |    critic_loss     | 8.88e+03  |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 3654      |
# |    reward          | 12.385935 |
# ----------------------------------
# day: 1217, episode: 25
# begin_total_asset: 1000000.00
# end_total_asset: 2791363.93
# total_reward: 1791363.93
# total_cost: 999.00
# total_trades: 10953
# Sharpe: 0.919
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 124       |
# |    time_elapsed    | 78        |
# |    total_timesteps | 9744      |
# | train/             |           |
# |    actor_loss      | -256      |
# |    critic_loss     | 3.91e+03  |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 8526      |
# |    reward          | 12.385935 |
# ----------------------------------
# ======DDPG Validation from:  2021-01-04 to  2021-04-09
# ======Best Model Retraining from:  2016-01-01 to  2021-04-09
# ======Trading from:  2021-04-09 to  2021-07-13
# ============================================
# turbulence_threshold:  375.90577053030336
# ======Model training from:  2016-01-01 to  2021-04-09
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_189_1
# -------------------------------------
# | time/                 |           |
# |    fps                | 266       |
# |    iterations         | 100       |
# |    time_elapsed       | 1         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -21.3     |
# |    explained_variance | -0.0168   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 104       |
# |    reward             | 1.1648142 |
# |    std                | 1         |
# |    value_loss         | 75.3      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 265         |
# |    iterations         | 200         |
# |    time_elapsed       | 3           |
# |    total_timesteps    | 1000        |
# | train/                |             |
# |    entropy_loss       | -21.3       |
# |    explained_variance | -0.0847     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 199         |
# |    policy_loss        | 230         |
# |    reward             | -0.13262703 |
# |    std                | 1           |
# |    value_loss         | 209         |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 263       |
# |    iterations         | 300       |
# |    time_elapsed       | 5         |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -21.3     |
# |    explained_variance | -0.862    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -16       |
# |    reward             | 0.8070164 |
# |    std                | 0.998     |
# |    value_loss         | 0.879     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 264       |
# |    iterations         | 400       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -21.3     |
# |    explained_variance | -0.000519 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 41.6      |
# |    reward             | 3.9960144 |
# |    std                | 0.998     |
# |    value_loss         | 44.5      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 264       |
# |    iterations         | 500       |
# |    time_elapsed       | 9         |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -21.2     |
# |    explained_variance | -0.000677 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 514       |
# |    reward             | 8.515237  |
# |    std                | 0.996     |
# |    value_loss         | 955       |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 262          |
# |    iterations         | 600          |
# |    time_elapsed       | 11           |
# |    total_timesteps    | 3000         |
# | train/                |              |
# |    entropy_loss       | -21.2        |
# |    explained_variance | -0.101       |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 599          |
# |    policy_loss        | 103          |
# |    reward             | -0.034574326 |
# |    std                | 0.994        |
# |    value_loss         | 28.6         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 264       |
# |    iterations         | 700       |
# |    time_elapsed       | 13        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -21.2     |
# |    explained_variance | -0.0599   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | 103       |
# |    reward             | -4.158217 |
# |    std                | 0.992     |
# |    value_loss         | 29.9      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 266        |
# |    iterations         | 800        |
# |    time_elapsed       | 15         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -21.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 3.91       |
# |    reward             | 0.24249086 |
# |    std                | 0.99       |
# |    value_loss         | 0.716      |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 268        |
# |    iterations         | 900        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -21.1      |
# |    explained_variance | -0.402     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | -46.2      |
# |    reward             | -1.8333586 |
# |    std                | 0.99       |
# |    value_loss         | 5.61       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 264        |
# |    iterations         | 1000       |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -21.2      |
# |    explained_variance | -0.00107   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | 23.4       |
# |    reward             | -1.0278115 |
# |    std                | 0.992      |
# |    value_loss         | 11         |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 264         |
# |    iterations         | 1100        |
# |    time_elapsed       | 20          |
# |    total_timesteps    | 5500        |
# | train/                |             |
# |    entropy_loss       | -21.2       |
# |    explained_variance | 0.0372      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1099        |
# |    policy_loss        | 2.64        |
# |    reward             | -0.05614487 |
# |    std                | 0.994       |
# |    value_loss         | 0.183       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 264        |
# |    iterations         | 1200       |
# |    time_elapsed       | 22         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -21.2      |
# |    explained_variance | -0.102     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -36        |
# |    reward             | -1.0369506 |
# |    std                | 0.992      |
# |    value_loss         | 4.83       |
# --------------------------------------
# day: 1280, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 2552224.18
# total_reward: 1552224.18
# total_cost: 26802.43
# total_trades: 16209
# Sharpe: 0.846
# =================================
# ----------------------------------------
# | time/                 |              |
# |    fps                | 263          |
# |    iterations         | 1300         |
# |    time_elapsed       | 24           |
# |    total_timesteps    | 6500         |
# | train/                |              |
# |    entropy_loss       | -21.1        |
# |    explained_variance | 5.96e-08     |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 1299         |
# |    policy_loss        | -33.7        |
# |    reward             | -0.119907126 |
# |    std                | 0.99         |
# |    value_loss         | 2.64         |
# ----------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 263       |
# |    iterations         | 1400      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -21.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 14.5      |
# |    reward             | 1.2015586 |
# |    std                | 0.991     |
# |    value_loss         | 7.8       |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 1500     |
# |    time_elapsed       | 28       |
# |    total_timesteps    | 7500     |
# | train/                |          |
# |    entropy_loss       | -21.2    |
# |    explained_variance | 0.0121   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1499     |
# |    policy_loss        | 417      |
# |    reward             | 34.89393 |
# |    std                | 0.992    |
# |    value_loss         | 415      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 264       |
# |    iterations         | 1600      |
# |    time_elapsed       | 30        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -21.2     |
# |    explained_variance | 0.00188   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -168      |
# |    reward             | 0.9080243 |
# |    std                | 0.992     |
# |    value_loss         | 81.5      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 263      |
# |    iterations         | 1700     |
# |    time_elapsed       | 32       |
# |    total_timesteps    | 8500     |
# | train/                |          |
# |    entropy_loss       | -21.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1699     |
# |    policy_loss        | -35      |
# |    reward             | 9.751016 |
# |    std                | 0.993    |
# |    value_loss         | 8.99     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 261      |
# |    iterations         | 1800     |
# |    time_elapsed       | 34       |
# |    total_timesteps    | 9000     |
# | train/                |          |
# |    entropy_loss       | -21.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 1799     |
# |    policy_loss        | -6.92    |
# |    reward             | -2.3994  |
# |    std                | 0.996    |
# |    value_loss         | 0.195    |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 261        |
# |    iterations         | 1900       |
# |    time_elapsed       | 36         |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -21.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | 66.1       |
# |    reward             | 0.07295918 |
# |    std                | 0.998      |
# |    value_loss         | 12.9       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 261       |
# |    iterations         | 2000      |
# |    time_elapsed       | 38        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -21.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | 37        |
# |    reward             | 2.6957085 |
# |    std                | 0.998     |
# |    value_loss         | 14.2      |
# -------------------------------------
# ======A2C Validation from:  2021-04-09 to  2021-07-13
# A2C Sharpe Ratio:  -0.037766406685534853
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 512}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_189_1
# ----------------------------------
# | time/              |           |
# |    fps             | 339       |
# |    iterations      | 1         |
# |    time_elapsed    | 6         |
# |    total_timesteps | 2048      |
# | train/             |           |
# |    reward          | 1.5932568 |
# ----------------------------------
# day: 1280, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 2454234.74
# total_reward: 1454234.74
# total_cost: 87782.01
# total_trades: 18695
# Sharpe: 0.964
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 333         |
# |    iterations           | 2           |
# |    time_elapsed         | 12          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.008233033 |
# |    clip_fraction        | 0.0784      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -21.3       |
# |    explained_variance   | -0.001      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 22.7        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.00919    |
# |    reward               | 0.21267194  |
# |    std                  | 1           |
# |    value_loss           | 60.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 334         |
# |    iterations           | 3           |
# |    time_elapsed         | 18          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.009980094 |
# |    clip_fraction        | 0.0889      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -21.3       |
# |    explained_variance   | -0.00917    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 28.4        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00879    |
# |    reward               | -7.630175   |
# |    std                  | 1           |
# |    value_loss           | 66          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 336         |
# |    iterations           | 4           |
# |    time_elapsed         | 24          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009579966 |
# |    clip_fraction        | 0.0671      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -21.3       |
# |    explained_variance   | -0.00541    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 44.8        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00806    |
# |    reward               | 1.8911533   |
# |    std                  | 1           |
# |    value_loss           | 93.6        |
# -----------------------------------------
# day: 1280, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 4708442.37
# total_reward: 3708442.37
# total_cost: 87655.50
# total_trades: 18639
# Sharpe: 1.434
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 336        |
# |    iterations           | 5          |
# |    time_elapsed         | 30         |
# |    total_timesteps      | 10240      |
# | train/                  |            |
# |    approx_kl            | 0.01053673 |
# |    clip_fraction        | 0.0877     |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -21.3      |
# |    explained_variance   | -0.0337    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 78.4       |
# |    n_updates            | 40         |
# |    policy_gradient_loss | -0.0109    |
# |    reward               | 4.20267    |
# |    std                  | 1          |
# |    value_loss           | 138        |
# ----------------------------------------
# ======PPO Validation from:  2021-04-09 to  2021-07-13
# PPO Sharpe Ratio:  -0.09618574575466202
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 512}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_189_1
# day: 1280, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 6598679.52
# total_reward: 5598679.52
# total_cost: 1024.35
# total_trades: 6460
# Sharpe: 1.382
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 138      |
# |    time_elapsed    | 37       |
# |    total_timesteps | 5124     |
# | train/             |          |
# |    actor_loss      | -120     |
# |    critic_loss     | 1.38e+03 |
# |    learning_rate   | 0.0005   |
# |    n_updates       | 3843     |
# |    reward          | 2.911558 |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 122      |
# |    time_elapsed    | 83       |
# |    total_timesteps | 10248    |
# | train/             |          |
# |    actor_loss      | -33.8    |
# |    critic_loss     | 471      |
# |    learning_rate   | 0.0005   |
# |    n_updates       | 8967     |
# |    reward          | 2.911558 |
# ---------------------------------
# ======DDPG Validation from:  2021-04-09 to  2021-07-13
# ======Best Model Retraining from:  2016-01-01 to  2021-07-13
# ======Trading from:  2021-07-13 to  2021-10-19
# ============================================
# turbulence_threshold:  375.90577053030336
# ======Model training from:  2016-01-01 to  2021-07-13
# ======A2C Training========
# {'n_steps': 5, 'ent_coef': 0.005, 'learning_rate': 0.0007}
# Using cuda device
# Logging to tensorboard_log/a2c/a2c_252_1
# -------------------------------------
# | time/                 |           |
# |    fps                | 246       |
# |    iterations         | 100       |
# |    time_elapsed       | 2         |
# |    total_timesteps    | 500       |
# | train/                |           |
# |    entropy_loss       | -21.2     |
# |    explained_variance | 0.052     |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 99        |
# |    policy_loss        | 78.4      |
# |    reward             | 2.1658394 |
# |    std                | 0.997     |
# |    value_loss         | 33.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 248        |
# |    iterations         | 200        |
# |    time_elapsed       | 4          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -21.2      |
# |    explained_variance | -0.0099    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | 109        |
# |    reward             | 0.47266537 |
# |    std                | 0.997      |
# |    value_loss         | 66.7       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 252        |
# |    iterations         | 300        |
# |    time_elapsed       | 5          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -21.2      |
# |    explained_variance | 0.0256     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | 34.5       |
# |    reward             | 0.12141132 |
# |    std                | 0.996      |
# |    value_loss         | 4.53       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 250       |
# |    iterations         | 400       |
# |    time_elapsed       | 7         |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -21.2     |
# |    explained_variance | 0.0329    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -145      |
# |    reward             | 2.4395347 |
# |    std                | 0.992     |
# |    value_loss         | 51.7      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 253        |
# |    iterations         | 500        |
# |    time_elapsed       | 9          |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -21.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | -203       |
# |    reward             | -2.7696009 |
# |    std                | 0.993      |
# |    value_loss         | 171        |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 254      |
# |    iterations         | 600      |
# |    time_elapsed       | 11       |
# |    total_timesteps    | 3000     |
# | train/                |          |
# |    entropy_loss       | -21.1    |
# |    explained_variance | 0.0957   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 599      |
# |    policy_loss        | -25.3    |
# |    reward             | 2.617444 |
# |    std                | 0.99     |
# |    value_loss         | 2.87     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 255        |
# |    iterations         | 700        |
# |    time_elapsed       | 13         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -21.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -150       |
# |    reward             | -2.2194874 |
# |    std                | 0.993      |
# |    value_loss         | 65.9       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 256      |
# |    iterations         | 800      |
# |    time_elapsed       | 15       |
# |    total_timesteps    | 4000     |
# | train/                |          |
# |    entropy_loss       | -21.1    |
# |    explained_variance | 0.0104   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 799      |
# |    policy_loss        | 128      |
# |    reward             | 7.439844 |
# |    std                | 0.99     |
# |    value_loss         | 144      |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 900       |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 4500      |
# | train/                |           |
# |    entropy_loss       | -21.1     |
# |    explained_variance | -0.0506   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 899       |
# |    policy_loss        | -186      |
# |    reward             | 3.9704342 |
# |    std                | 0.988     |
# |    value_loss         | 113       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 255        |
# |    iterations         | 1000       |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -21.1      |
# |    explained_variance | -0.0121    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | -12.5      |
# |    reward             | -0.9308802 |
# |    std                | 0.988      |
# |    value_loss         | 4.8        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 255         |
# |    iterations         | 1100        |
# |    time_elapsed       | 21          |
# |    total_timesteps    | 5500        |
# | train/                |             |
# |    entropy_loss       | -21.1       |
# |    explained_variance | -0.0454     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1099        |
# |    policy_loss        | 46.5        |
# |    reward             | -0.12870716 |
# |    std                | 0.987       |
# |    value_loss         | 10.1        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 256        |
# |    iterations         | 1200       |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -21.1      |
# |    explained_variance | -0.152     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -22.8      |
# |    reward             | 0.19994627 |
# |    std                | 0.988      |
# |    value_loss         | 5.39       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 256       |
# |    iterations         | 1300      |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 6500      |
# | train/                |           |
# |    entropy_loss       | -21.1     |
# |    explained_variance | 0.0453    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1299      |
# |    policy_loss        | -84.9     |
# |    reward             | 3.8349636 |
# |    std                | 0.986     |
# |    value_loss         | 20.7      |
# -------------------------------------
# day: 1343, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 2267108.30
# total_reward: 1267108.30
# total_cost: 44393.90
# total_trades: 14657
# Sharpe: 0.768
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 257        |
# |    iterations         | 1400       |
# |    time_elapsed       | 27         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -21.1      |
# |    explained_variance | -0.245     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 20.7       |
# |    reward             | 0.41707623 |
# |    std                | 0.989      |
# |    value_loss         | 1.93       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 257        |
# |    iterations         | 1500       |
# |    time_elapsed       | 29         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -21.1      |
# |    explained_variance | -0.0107    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | -64.1      |
# |    reward             | -0.8410884 |
# |    std                | 0.989      |
# |    value_loss         | 25.7       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 257        |
# |    iterations         | 1600       |
# |    time_elapsed       | 31         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -21.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 22.8       |
# |    reward             | 0.35019112 |
# |    std                | 0.986      |
# |    value_loss         | 3.32       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 257        |
# |    iterations         | 1700       |
# ...
# |    entropy_loss       | -21.3      |
# |    explained_variance | 0.0968     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 399        |
# |    policy_loss        | -18.6      |
# |    reward             | -1.8405479 |
# |    std                | 1          |
# |    value_loss         | 2.93       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 225         |
# |    iterations         | 500         |
# |    time_elapsed       | 11          |
# |    total_timesteps    | 2500        |
# | train/                |             |
# |    entropy_loss       | -21.3       |
# |    explained_variance | -0.165      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 499         |
# |    policy_loss        | 61.9        |
# |    reward             | -0.23696558 |
# |    std                | 1           |
# |    value_loss         | 8.47        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 227        |
# |    iterations         | 600        |
# |    time_elapsed       | 13         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -21.3      |
# |    explained_variance | -0.0377    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | 2.46       |
# |    reward             | -0.6977537 |
# |    std                | 1          |
# |    value_loss         | 4.33       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 229         |
# |    iterations         | 700         |
# |    time_elapsed       | 15          |
# |    total_timesteps    | 3500        |
# | train/                |             |
# |    entropy_loss       | -21.4       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 699         |
# |    policy_loss        | 3.14        |
# |    reward             | -0.11671963 |
# |    std                | 1.01        |
# |    value_loss         | 0.0858      |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 230       |
# |    iterations         | 800       |
# |    time_elapsed       | 17        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -21.4     |
# |    explained_variance | -0.0757   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -0.163    |
# |    reward             | 1.0184844 |
# |    std                | 1.01      |
# |    value_loss         | 1.29      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 231        |
# |    iterations         | 900        |
# |    time_elapsed       | 19         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -21.4      |
# |    explained_variance | 0.0736     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 16.1       |
# |    reward             | -1.3674039 |
# |    std                | 1.01       |
# |    value_loss         | 4.63       |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 228          |
# |    iterations         | 1000         |
# |    time_elapsed       | 21           |
# |    total_timesteps    | 5000         |
# | train/                |              |
# |    entropy_loss       | -21.4        |
# |    explained_variance | 0.118        |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 999          |
# |    policy_loss        | 9.09         |
# |    reward             | -0.124102265 |
# |    std                | 1.01         |
# |    value_loss         | 0.815        |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 224        |
# |    iterations         | 1100       |
# |    time_elapsed       | 24         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -21.4      |
# |    explained_variance | -2.38e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | 83.5       |
# |    reward             | -0.9146775 |
# |    std                | 1.01       |
# |    value_loss         | 18.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 223       |
# |    iterations         | 1200      |
# |    time_elapsed       | 26        |
# |    total_timesteps    | 6000      |
# | train/                |           |
# |    entropy_loss       | -21.4     |
# |    explained_variance | -0.175    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1199      |
# |    policy_loss        | -179      |
# |    reward             | 1.3992472 |
# |    std                | 1.01      |
# |    value_loss         | 74.3      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 224        |
# |    iterations         | 1300       |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -21.4      |
# |    explained_variance | -0.436     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | -16.8      |
# |    reward             | -0.3048229 |
# |    std                | 1.01       |
# |    value_loss         | 1.42       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 225       |
# |    iterations         | 1400      |
# |    time_elapsed       | 31        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -21.4     |
# |    explained_variance | -0.123    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | -16.9     |
# |    reward             | 0.4999103 |
# |    std                | 1.01      |
# |    value_loss         | 1.93      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 226        |
# |    iterations         | 1500       |
# |    time_elapsed       | 33         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -21.4      |
# |    explained_variance | 0.025      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | 148        |
# |    reward             | -3.3504708 |
# |    std                | 1.01       |
# |    value_loss         | 74.2       |
# --------------------------------------
# day: 1532, episode: 5
# begin_total_asset: 1000000.00
# end_total_asset: 1482606.30
# total_reward: 482606.30
# total_cost: 34344.69
# total_trades: 17467
# Sharpe: 0.370
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 227        |
# |    iterations         | 1600       |
# |    time_elapsed       | 35         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -21.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 50.7       |
# |    reward             | 0.57968146 |
# |    std                | 1.01       |
# |    value_loss         | 5.45       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 228       |
# |    iterations         | 1700      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -21.5     |
# |    explained_variance | 0.0569    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | -20.4     |
# |    reward             | 5.3188815 |
# |    std                | 1.01      |
# |    value_loss         | 1.33      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 228         |
# |    iterations         | 1800        |
# |    time_elapsed       | 39          |
# |    total_timesteps    | 9000        |
# | train/                |             |
# |    entropy_loss       | -21.5       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1799        |
# |    policy_loss        | -41.1       |
# |    reward             | -0.28754675 |
# |    std                | 1.02        |
# |    value_loss         | 32          |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 226       |
# |    iterations         | 1900      |
# |    time_elapsed       | 41        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -21.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 4.41      |
# |    reward             | 0.0686722 |
# |    std                | 1.02      |
# |    value_loss         | 0.183     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 224       |
# |    iterations         | 2000      |
# |    time_elapsed       | 44        |
# |    total_timesteps    | 10000     |
# | train/                |           |
# |    entropy_loss       | -21.5     |
# |    explained_variance | -0.041    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1999      |
# |    policy_loss        | -94.9     |
# |    reward             | 1.0135947 |
# |    std                | 1.02      |
# |    value_loss         | 28.1      |
# -------------------------------------
# ======A2C Validation from:  2022-04-25 to  2022-07-27
# A2C Sharpe Ratio:  -0.0744765213143024
# ======PPO Training========
# {'ent_coef': 0.01, 'n_steps': 2048, 'learning_rate': 0.00025, 'batch_size': 512}
# Using cuda device
# Logging to tensorboard_log/ppo/ppo_441_1
# -----------------------------------
# | time/              |            |
# |    fps             | 229        |
# |    iterations      | 1          |
# |    time_elapsed    | 8          |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.74649096 |
# -----------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 233          |
# |    iterations           | 2            |
# |    time_elapsed         | 17           |
# |    total_timesteps      | 4096         |
# | train/                  |              |
# |    approx_kl            | 0.0073186457 |
# |    clip_fraction        | 0.106        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -21.3        |
# |    explained_variance   | -0.00612     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 44           |
# |    n_updates            | 10           |
# |    policy_gradient_loss | -0.00847     |
# |    reward               | 1.3107728    |
# |    std                  | 1            |
# |    value_loss           | 94.7         |
# ------------------------------------------
# day: 1532, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 3208726.20
# total_reward: 2208726.20
# total_cost: 124667.48
# total_trades: 22453
# Sharpe: 0.948
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 233         |
# |    iterations           | 3           |
# |    time_elapsed         | 26          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.00556002  |
# |    clip_fraction        | 0.0708      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -21.3       |
# |    explained_variance   | 0.00513     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 16.6        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.00678    |
# |    reward               | -0.17073476 |
# |    std                  | 1           |
# |    value_loss           | 35.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 231         |
# |    iterations           | 4           |
# |    time_elapsed         | 35          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009877007 |
# |    clip_fraction        | 0.0942      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -21.3       |
# |    explained_variance   | 0.0051      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 93.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.00827    |
# |    reward               | -1.9135298  |
# |    std                  | 1           |
# |    value_loss           | 175         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 230         |
# |    iterations           | 5           |
# |    time_elapsed         | 44          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.008460282 |
# |    clip_fraction        | 0.0871      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -21.4       |
# |    explained_variance   | -0.0395     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.48        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0087     |
# |    reward               | -1.0272123  |
# |    std                  | 1.01        |
# |    value_loss           | 13.7        |
# -----------------------------------------
# ======PPO Validation from:  2022-04-25 to  2022-07-27
# PPO Sharpe Ratio:  0.13992599769333874
# ======DDPG Training========
# {'buffer_size': 10000, 'learning_rate': 0.0005, 'batch_size': 512}
# Using cuda device
# Logging to tensorboard_log/ddpg/ddpg_441_1
# day: 1532, episode: 15
# begin_total_asset: 1000000.00
# end_total_asset: 4343986.90
# total_reward: 3343986.90
# total_cost: 3292.67
# total_trades: 13075
# Sharpe: 1.026
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 111       |
# |    time_elapsed    | 54        |
# |    total_timesteps | 6132      |
# | train/             |           |
# |    actor_loss      | 18.9      |
# |    critic_loss     | 2.09e+03  |
# |    learning_rate   | 0.0005    |
# |    n_updates       | 4599      |
# |    reward          | -1.463155 |
# ----------------------------------
# day: 1532, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 3980269.61
# total_reward: 2980269.61
# total_cost: 1199.12
# total_trades: 12336
# Sharpe: 0.948
# =================================
# ======DDPG Validation from:  2022-04-25 to  2022-07-27
# ======Best Model Retraining from:  2016-01-01 to  2022-07-27
# ======Trading from:  2022-07-27 to  2022-11-01
# Ensemble Strategy took:  17.348793562253316  minutes

# %%
df_summary
# Out:
#   Iter   Val Start     Val End Model Used A2C Sharpe PPO Sharpe DDPG Sharpe
# 0  126  2021-01-04  2021-04-09       DDPG   0.012352   0.014776    0.020789
# 1  189  2021-04-09  2021-07-13        A2C  -0.037766  -0.096186   -0.051221
# 2  252  2021-07-13  2021-10-19        PPO  -0.179455   0.093198   -0.088035
# 3  315  2021-10-19  2022-01-17       DDPG  -0.058785  -0.083726    0.029323
# 4  378  2022-01-17  2022-04-25        PPO  -0.166937  -0.097698   -0.187045
# 5  441  2022-04-25  2022-07-27       DDPG  -0.074477   0.139926    0.248799

# %%
df_account_value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 df_account_value
#
# NameError: name 'df_account_value' is not defined

# %%
unique_trade_date = processed[(processed.date > TEST_START_DATE)&(processed.date <= TEST_END_DATE)].date.unique()
print(unique_trade_date.shape)
df_trade_date = pd.DataFrame({'datadate':unique_trade_date})

df_account_value=pd.DataFrame()
for i in range(rebalance_window+validation_window, len(unique_trade_date)+1,rebalance_window):
    temp = pd.read_csv('results/account_value_trade_{}_{}.csv'.format('ensemble',i))
    df_account_value = df_account_value.append(temp,ignore_index=True)
sharpe=(252**0.5)*df_account_value.account_value.pct_change(1).mean()/df_account_value.account_value.pct_change(1).std()
print('Sharpe Ratio: ',sharpe)
df_account_value=df_account_value.join(df_trade_date[validation_window:].reset_index(drop=True))
# %matplotlib inline
df_account_value['date'] = pd.to_datetime(df_account_value['date'])
df_account_value.plot(x='date',y='account_value',legend=False)
plt.xlabel('Date')
plt.ylabel('Account Value')
# df_account_value.account_value.plot(xlabel='Date',ylabel='Account Value')
# set name of x axis: Date
# Out:
# (485,)
# Sharpe Ratio:  -1.3932644884089462
# Text(0, 0.5, 'Account Value')

# %%
new_end_date = '2022-01-01'
df_account_value = df_account_value[df_account_value['date'] <= new_end_date]

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
# Out:
# ==============Get Backtest Results===========
# Annual return         -0.304888
# Cumulative returns    -0.228773
# Annual volatility      0.357833
# Sharpe ratio          -0.841984
# Calmar ratio          -0.852595
# Stability              0.807931
# Max drawdown          -0.357600
# Omega ratio            0.868539
# Sortino ratio         -1.119003
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.090961
# Daily value at risk   -0.046278
# dtype: float64

# %%
print("==============Get Baseline Stats===========")
baseline_df = pd.read_csv('../ResMom15Macro/datasets/csi300.csv')
baseline_df = baseline_df[baseline_df['date'] <= new_end_date]
stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# Annual return          0.062881
# Cumulative returns     0.424122
# Annual volatility      0.194388
# Sharpe ratio           0.411575
# Calmar ratio           0.193706
# Stability              0.699828
# Max drawdown          -0.324620
# Omega ratio            1.076868
# Sortino ratio          0.566911
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.052678
# Daily value at risk   -0.024173
# dtype: float64

# %%
print("==============Compare to SSE 50 Index===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
              baseline_ticker = 'CSI300', 
              baseline_start = df_account_value.loc[0,'date'],
              baseline_end = df_account_value.loc[len(df_account_value)-1,'date'], baseline_df = baseline_df)
# Out:
# ==============Compare to SSE 50 Index===========
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2021-04-09</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-12-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>8</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>-30.489%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>-22.877%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>35.783%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>-0.84</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>-0.85</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.81</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-35.76%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>0.87</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>-1.12</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.09</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-4.628%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>-0.25</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>1.33</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>35.76</td>
#       <td>2021-05-27</td>
#       <td>2021-12-02</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>5.04</td>
#       <td>2021-04-28</td>
#       <td>2021-05-07</td>
#       <td>2021-05-17</td>
#       <td>14</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2.05</td>
#       <td>2021-05-19</td>
#       <td>2021-05-21</td>
#       <td>2021-05-25</td>
#       <td>5</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>0.66</td>
#       <td>2021-04-09</td>
#       <td>2021-04-13</td>
#       <td>2021-04-14</td>
#       <td>4</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>0.43</td>
#       <td>2021-05-17</td>
#       <td>2021-05-18</td>
#       <td>2021-05-19</td>
#       <td>3</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>-0.12%</td>
#       <td>-9.23%</td>
#       <td>5.15%</td>
#     </tr>
#   </tbody>
# </table>

# %%
total_return_rate
# Out:
# 0.10222773167000065

# %%
len(df_account_value)
# Out:
# 189

# %%
# 计算年化收益率

total_return_rate = df_account_value.account_value.values[-1] / 1e6  - 1
annual_return_rate = (1 + total_return_rate) ** (250 / len(df_account_value)) - 1
print('年化收益率：', annual_return_rate)
# Out:
# 年化收益率： 0.13740324337855592

# %%
df_account_value.head(10)
# Out:
#    account_value       date  daily_return    datadate
# 0   1.000000e+06 2020-11-06           NaN  2020-11-06
# 1   1.003903e+06 2020-11-09      0.003903  2020-11-09
# 2   1.003663e+06 2020-11-10     -0.000239  2020-11-10
# 3   1.002640e+06 2020-11-11     -0.001020  2020-11-11
# 4   1.002187e+06 2020-11-12     -0.000452  2020-11-12
# 5   1.001421e+06 2020-11-13     -0.000764  2020-11-13
# 6   1.001776e+06 2020-11-16      0.000354  2020-11-16
# 7   1.000769e+06 2020-11-17     -0.001006  2020-11-17
# 8   9.994531e+05 2020-11-18     -0.001314  2020-11-18
# 9   1.003087e+06 2020-11-19      0.003636  2020-11-19

# %%
# 分别画出 processed 数据中每只股票的close的折线图
for i in range(len(ticket_list)):
    plt.plot(processed[processed.tic == ticket_list[i]].date, processed[processed.tic == ticket_list[i]].close)
plt.legend(ticket_list)

# %%
# 画出 processed 数据中每只股票的close的平均值的折线图，每个date只画一次
processed_mean = processed.groupby('date').mean()
processed_mean['date'] = pd.to_datetime(processed_mean.index)
plt.plot(processed_mean.date, processed_mean.close)

# %%
processed.groupby('date')

# %%
# 计算股票在每个date的体量百分比和所有股票体量的加权和



# processed['volume_pct'] = processed.groupby('date')['volume'].apply(lambda x: x / x.sum())

# plot processed 数据中的close按照股票体量的加权和 区分训练集和测试集，每个date只画一次
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1567, in GroupBy.apply(self, func, *args, **kwargs)
#    1564     with rewrite_warning(
#    1565         old_msg, FutureWarning, new_msg
#    1566     ) if is_np_func else nullcontext():
# -> 1567         result = self._python_apply_general(f, self._selected_obj)
#    1568 except TypeError:
#    1569     # gh-20949
#    1570     # try again, with .apply acting as a filtering
#    (...)
#    1574     # fails on *some* columns, e.g. a numeric operation
#    1575     # on a string grouper column
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1629, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1601 """
#    1602 Apply function f in python space
#    1603
#    (...)
#    1627     data after applying f
#    1628 """
# -> 1629 values, mutated = self.grouper.apply(f, data, self.axis)
#    1630 if not_indexed_same is None:
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/groupby/ops.py:839, in BaseGrouper.apply(self, f, data, axis)
#     838 group_axes = group.axes
# --> 839 res = f(group)
#     840 if not mutated and not _is_indexed_like(res, group_axes, axis):
#
# Cell In[51], line 5, in <lambda>(x)
#       4 # plot processed 数据中的close按照股票体量的加权和 区分训练集和测试集，每个date只画一次
# ----> 5 plt.plot(processed[processed.date <= TRAIN_END_DATE].groupby('date')['close'].apply(lambda x: np.average(x, weights=processed[processed.date <= TRAIN_END_DATE].groupby('date')['volume'].apply(lambda x: x / x.sum()))), label='train')
#       6 plt.plot(processed[processed.date > TRAIN_END_DATE].groupby('date')['close'].apply(lambda x: np.average(x, weights=processed[processed.date > TRAIN_END_DATE].groupby('date')['volume'].apply(lambda x: x / x.sum()))), label='test')
#
# File <__array_function__ internals>:200, in average(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:532, in average(a, axis, weights, returned, keepdims)
#     531 if axis is None:
# --> 532     raise TypeError(
#     533         "Axis must be specified when shapes of a and weights "
#     534         "differ.")
#     535 if wgt.ndim != 1:
#
# TypeError: Axis must be specified when shapes of a and weights differ.
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 5
#       2 processed['volume_pct'] = processed.groupby('date')['volume'].apply(lambda x: x / x.sum())
#       4 # plot processed 数据中的close按照股票体量的加权和 区分训练集和测试集，每个date只画一次
# ----> 5 plt.plot(processed[processed.date <= TRAIN_END_DATE].groupby('date')['close'].apply(lambda x: np.average(x, weights=processed[processed.date <= TRAIN_END_DATE].groupby('date')['volume'].apply(lambda x: x / x.sum()))), label='train')
#       6 plt.plot(processed[processed.date > TRAIN_END_DATE].groupby('date')['close'].apply(lambda x: np.average(x, weights=processed[processed.date > TRAIN_END_DATE].groupby('date')['volume'].apply(lambda x: x / x.sum()))), label='test')
#       7 plt.legend()
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/groupby/generic.py:254, in SeriesGroupBy.apply(self, func, *args, **kwargs)
#     248 @Appender(
#     249     _apply_docs["template"].format(
#     250         input="series", examples=_apply_docs["series_examples"]
#     251     )
#     252 )
#     253 def apply(self, func, *args, **kwargs) -> Series:
# --> 254     return super().apply(func, *args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1588, in GroupBy.apply(self, func, *args, **kwargs)
#    1580             new_msg = (
#    1581                 f"The operation {orig_func} failed on a column. If any error "
#    1582                 f"is raised, this will raise an exception in a future version "
#    1583                 f"of pandas. Drop these columns to avoid this warning."
#    1584             )
#    1585             with rewrite_warning(
#    1586                 old_msg, FutureWarning, new_msg
#    1587             ) if is_np_func else nullcontext():
# -> 1588                 return self._python_apply_general(f, self._selected_obj)
#    1590 return result
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/groupby/groupby.py:1629, in GroupBy._python_apply_general(self, f, data, not_indexed_same, is_transform, is_agg)
#    1592 @final
#    1593 def _python_apply_general(
#    1594     self,
#    (...)
#    1599     is_agg: bool = False,
#    1600 ) -> NDFrameT:
#    1601     """
#    1602     Apply function f in python space
#    1603
#    (...)
#    1627         data after applying f
#    1628     """
# -> 1629     values, mutated = self.grouper.apply(f, data, self.axis)
#    1630     if not_indexed_same is None:
#    1631         not_indexed_same = mutated or self.mutated
#
# File ~/.local/lib/python3.8/site-packages/pandas/core/groupby/ops.py:839, in BaseGrouper.apply(self, f, data, axis)
#     837 # group might be modified
#     838 group_axes = group.axes
# --> 839 res = f(group)
#     840 if not mutated and not _is_indexed_like(res, group_axes, axis):
#     841     mutated = True
#
# Cell In[51], line 5, in <lambda>(x)
#       2 processed['volume_pct'] = processed.groupby('date')['volume'].apply(lambda x: x / x.sum())
#       4 # plot processed 数据中的close按照股票体量的加权和 区分训练集和测试集，每个date只画一次
# ----> 5 plt.plot(processed[processed.date <= TRAIN_END_DATE].groupby('date')['close'].apply(lambda x: np.average(x, weights=processed[processed.date <= TRAIN_END_DATE].groupby('date')['volume'].apply(lambda x: x / x.sum()))), label='train')
#       6 plt.plot(processed[processed.date > TRAIN_END_DATE].groupby('date')['close'].apply(lambda x: np.average(x, weights=processed[processed.date > TRAIN_END_DATE].groupby('date')['volume'].apply(lambda x: x / x.sum()))), label='test')
#       7 plt.legend()
#
# File <__array_function__ internals>:200, in average(*args, **kwargs)
#
# File ~/.local/lib/python3.8/site-packages/numpy/lib/function_base.py:532, in average(a, axis, weights, returned, keepdims)
#     530 if a.shape != wgt.shape:
#     531     if axis is None:
# --> 532         raise TypeError(
#     533             "Axis must be specified when shapes of a and weights "
#     534             "differ.")
#     535     if wgt.ndim != 1:
#     536         raise TypeError(
#     537             "1D weights expected when shapes of a and weights differ.")
#
# TypeError: Axis must be specified when shapes of a and weights differ.

# %%
# plot baseline_df 数据中的close 区分训练集和测试集
plt.plot(baseline_df[baseline_df.date <= TRAIN_END_DATE].date, baseline_df[baseline_df.date <= TRAIN_END_DATE].close)
plt.plot(baseline_df[(baseline_df.date > TRAIN_END_DATE) & (baseline_df.date <= TEST_END_DATE)].date, baseline_df[(baseline_df.date > TRAIN_END_DATE) & (baseline_df.date <= TEST_END_DATE)].close)
plt.plot(baseline_df[baseline_df.date > TEST_END_DATE].date, baseline_df[baseline_df.date > TEST_END_DATE].close)
plt.legend(['train period', 'test period', 'validation period'])
plt.title('SSE 50 Index (benchmark, not for training)')
plt.savefig('outputs/SSE50IndexStock0308/SSE50Index.png')
plt.xlabel('Date')
# Out:
# Text(0.5, 23.52222222222222, 'Date')

# %%
processed.columns
# Out:
# Index(['tic', 'date', 'open', 'high', 'low', 'close', 'volume', 'day', 'macd',
#        'boll_ub', 'boll_lb', 'rsi_30', 'cci_30', 'dx_30', 'close_30_sma',
#        'close_60_sma', 'turbulence', 'turnover_rate', 'pb'],
#       dtype='object')
